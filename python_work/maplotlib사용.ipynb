# %%
# %matplotlib inline 
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import rc, font_manager

# %%
data=np.random.rand(50)
print(type(data))
print(data)
# Out:
# <class 'numpy.ndarray'>
# [0.39655214 0.8751118  0.97672921 0.25884873 0.27267872 0.29443429
#  0.10223886 0.46181782 0.10066485 0.53849876 0.07743313 0.75239843
#  0.70357905 0.40543671 0.63843818 0.76292212 0.16300502 0.29076616
#  0.04361618 0.26527819 0.67665708 0.59969491 0.83947034 0.25499264
#  0.58105495 0.21578568 0.38074901 0.75388953 0.07334227 0.23138476
#  0.33075956 0.0307431  0.31893621 0.62694186 0.47742663 0.65911361
#  0.32052115 0.88296112 0.12977319 0.32437203 0.33928874 0.92719922
#  0.66977638 0.89724758 0.85864028 0.04084811 0.32525866 0.13791397
#  0.35703561 0.67620357]

# %%
seri=pd.Series(data)
print(type(seri))
print(seri)
# Out:
# <class 'pandas.core.series.Series'>
# 0     0.396552
# 1     0.875112
# 2     0.976729
# 3     0.258849
# 4     0.272679
# 5     0.294434
# 6     0.102239
# 7     0.461818
# 8     0.100665
# 9     0.538499
# 10    0.077433
# 11    0.752398
# 12    0.703579
# 13    0.405437
# 14    0.638438
# 15    0.762922
# 16    0.163005
# 17    0.290766
# 18    0.043616
# 19    0.265278
# 20    0.676657
# 21    0.599695
# 22    0.839470
# 23    0.254993
# 24    0.581055
# 25    0.215786
# 26    0.380749
# 27    0.753890
# 28    0.073342
# 29    0.231385
# 30    0.330760
# 31    0.030743
# 32    0.318936
# 33    0.626942
# 34    0.477427
# 35    0.659114
# 36    0.320521
# 37    0.882961
# 38    0.129773
# 39    0.324372
# 40    0.339289
# 41    0.927199
# 42    0.669776
# 43    0.897248
# 44    0.858640
# 45    0.040848
# 46    0.325259
# 47    0.137914
# 48    0.357036
# 49    0.676204
# dtype: float64

# %%
seri.plot()
# Out:
# <AxesSubplot:>

# %%
matplotlib.style.use("ggplot")
seri.plot()
# Out:
# <AxesSubplot:>

# %%
data_set=np.random.rand(10,3)
df=pd.DataFrame(data_set,columns=['A','B','C'])
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#           A         B         C
# 0  0.773593  0.330853  0.105109
# 1  0.165737  0.278320  0.224469
# 2  0.701373  0.085005  0.448550
# 3  0.566021  0.097905  0.260986
# 4  0.023154  0.299419  0.221245
# 5  0.491262  0.211494  0.525078
# 6  0.155098  0.147478  0.118076
# 7  0.471713  0.324510  0.659942
# 8  0.349147  0.685477  0.106238
# 9  0.474099  0.425138  0.530353

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area', stacked=False)
# Out:
# <AxesSubplot:>

# %%
seri2=pd.Series(np.random.rand(5),index=['A','B','C','D','E'],name='Series')
seri2.plot(kind='pie',autopct='%.2f',fontsize=16,figsize=(5,5))
# Out:
# <AxesSubplot:ylabel='Series'>

# %%
from matplotlib import rc, font_manager
font_name=font_manager.FontProperties(fname='c:/Windows/Fonts/batang.ttc').get_name()
rc('font',family=font_name)

df=pd.DataFrame(np.random.randn(10,4),columns=['가','나','다','라'],index=np.arange(0,100,10))
df.plot()
# Out:
# <AxesSubplot:>

# %%
df1=pd.DataFrame(np.random.rand(6,4),
                 index=['one','two','three','four','five','six'],
                 columns=pd.Index(['가','나','다','라'], name="종류"))

# %%
plt.rcParams['axes.unicode_minus']=False
df1.plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:>

# %%
s3=pd.Series(np.random.normal(0,100,size=200))
s3.head()
# Out:
# 0    -61.118585
# 1    136.600634
# 2   -109.255134
# 3    -47.376302
# 4    -29.031285
# dtype: float64

# %%
plt.rcParams['axes.unicode_minus']=False
#축 구간 기본값으로 10 히스토그램
s3.hist()
# Out:
# <AxesSubplot:>

# %%
#축 구간 기본값으로 50
s3.hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
#산점도 : 서로 다른 독립변수 x1,x2의 관계를 파악
#normal(mu,sigma,size(rows,cols)) mu중앙값, sigma표준편차
x1=np.random.normal(1,1,size=(100,1))
x2=np.random.normal(-2,4,size=(100,1))
#concatenate:열방향 연결, axis=1 가로, 0 세로
x=np.concatenate((x1,x2),axis=1)
print(x[:5])
df3=pd.DataFrame(x,columns=['x1','x2'])
df3.head()
# Out:
# [[  0.64772377   0.50951678]
#  [ -0.25008192   0.7810135 ]
#  [  0.85347995  -4.91254585]
#  [  2.1074128   -3.63575106]
#  [  1.1001449  -11.50628114]]
#          x1         x2
# 0  0.647724   0.509517
# 1 -0.250082   0.781013
# 2  0.853480  -4.912546
# 3  2.107413  -3.635751
# 4  1.100145 -11.506281

# %%
plt.scatter(df3.x1,df3.x2)

# %%
h=[100,200,300,400,500,600,700,800,900,1000]
t=[20,18,15,14,12,11,10,9,8,7]

data={'h':h,'t':t}
df=pd.DataFrame(data)
plt.scatter(df.h,df.t)

# %%
print(df.h.corr(df.t))
print(df3.x1.corr(df3.x2))
# Out:
# -0.9815088166234459
# -0.12135243457820562

# %%
import csv
from datetime import datetime
filename='data/temperature_2014.csv'
with open(filename) as f:
    reader=csv.reader(f)
    header_row=next(reader)
    dates,highs,lows=[],[],[]
    for row in reader:
        try:
            #strftime : 날짜 -> 문자
            #strptime : 문자 -> 날짜
            current_date=datetime.strptime(row[0],'%Y-%m-%d')
            high=int(row[1])
            low=int(row[3])
        except ValueError:
            print(current_date,'missing date')
        else:
            dates.append(current_date)
            highs.append(high)
            lows.append(low)
            
flg=plt.figure(dpi=128,figsize=(10,6))
plt.plot(dates,highs,c='red',alpha=0.5)
plt.plot(dates,lows,c='blue',alpha=0.5)
plt.fill_between(dates,highs,lows,facecolor='blue',alpha=0.1)

plt.title('온도 통계',fontsize=20)
plt.xlabel('기간',fontsize=16)
plt.ylabel('온도',fontsize=16)
plt.tick_params(axis='both',labelsize=16)

plt.savefig('data/temperature_plot.png', dpi=400, bbox_inches='tight')
plt.show()
# Out:
# 2014-02-16 00:00:00 missing date

# %%
plt.figure()
plt.subplot(2,1,1)
plt.plot([1,2,3,4],[1,2,3,4])
plt.subplot(2,1,2)
plt.plot([5,6,7,8],[5,6,7,8])
plt.show()

# %%
plt.figure()
plt.subplot(1,2,1)
plt.plot([1,2,3,4],[1,2,3,4])
plt.subplot(1,2,2)
plt.plot([5,6,7,8],[5,6,7,8])
plt.show()

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot([1,2,3,4],[1,2,3,4])
plt.subplot(2,2,2)
plt.plot([5,6,7,8],[5,6,7,8])
plt.show()

# %%
plt.plot([1,2,3,4],[1,2,3,4])
plt.xlabel('x축')
plt.ylabel('y축')
plt.title('maplotlib 활용')
plt.text(3.5, 3.0, '평균:2.5')
plt.grid(True)
plt.show()
