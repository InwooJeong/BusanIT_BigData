# %%
from selenium import webdriver
import time

# %%
driver=webdriver.Chrome('chromedriver')
driver.implicitly_wait(3)
driver.get('http://www.yes24.com/Product/Goods/74419916')
time.sleep(2)

readLinks=driver.find_elements_by_css_selector('#infoset_reviewContentList div.reviewInfoBot.crop > a')
for readLink in readLinks:
    readLink.click()
    time.sleep(1)
    
review_list=driver.find_elements_by_css_selector('#infoset_reviewContentList div.reviewInfoBot.origin > div.review_cont')
temp_list=[]
time.sleep(2)

for review in review_list:
    temp_list.append(review.text)
print(temp_list)

stopFlag=False

while True:
    for n in range(4,13):
        linkurl='#infoset_reviewContentList > div.review_sort.sortBot > div.review_sortLft > div > a:nth-child('+str(n)+')'
        linkNum=driver.find_element_by_css_selector(linkurl)
        linkNum.click()
        time.sleep(2)
        readLinks=driver.find_elements_by_css_selector('#infoset_reviewContentList div.reviewInfoBot.crop > a')
        for readLink in readLinks:
            readLink.click()
            time.sleep(1)
            
        review_list=driver.find_elements_by_css_selector('#infoset_reviewContentList div.reviewInfoBot.origin > div.review_cont')
        time.sleep(2)
        for review in review_list:
            temp_list.append(review.text)
            
        if len(review_list)<5:
            stopFlag=True
            break
    
    if stopFlag==True:
        break
        
    nextBlock='#infoset_reviewContentList > div.review_sort.sortBot > div.review_sortLft > div > a.bgYUI.next'
    linkNext=driver.find_element_by_css_selector(nextBlock)
    linkNext.click()
    time.sleep(1)
# Out:
# <ipython-input-13-b7459bc2bbe0>:6: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   readLinks=driver.find_elements_by_css_selector('#infoset_reviewContentList div.reviewInfoBot.crop > a')
# <ipython-input-13-b7459bc2bbe0>:11: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   review_list=driver.find_elements_by_css_selector('#infoset_reviewContentList div.reviewInfoBot.origin > div.review_cont')
# ['박응용님의 <Do it! 점프 투 파이썬> 리뷰입니다.\n파이썬을 처음 접하면서 베스트셀러에 있는 책을 구매하게되었는데요. \n설명이 굉장히 쉽게 되어있고 온라인 강의도 포함되어 있는 것 같아서 좋았습니다. \n온라인 강의는 들어보진 않았지만 책으로도 충분히 이해가 되어 만족스러웠습니다.!!!\n개념을 확실히 이해하기 좋은 책인 것 같도 다른 시리즈들은 실습하기 좋은 것 같더라고요 ~~ \n ', '정말 파이썬의 기본적인 문법을 알기에 좋아요\n또한 다른 언어랑도 비교 및 객체에 대해서 잘 설명해주고\n  언어가 어떻게 돌아가는지 등에 대해서도 잘 알려주기 때문에 언어의 입문으로는 정말 좋다고 생각합니다.\n기본적인 언어에 대해서는 정말 잘 설명되어있고 그외에 간단한 응용은 잘 설명이 되어있습니다.\n  하지만 심화 과정은 그리 깊게 들어있지않아 이 책 하나로 끝내기는 어렵습니다.\n  다만 심화과정은 따로 책을 구비하셔야 합니다.\n ', '모든 입문서가 이 책은 초보라도 할 수 있다고 말하지만 이 책은 정말로 초보도 할 수 있을 정도로 상세하고 친절하게 처음부터 알려준다. 개인적으로 이 책으로 파이썬 공부를 시작하게 되어서 정말 다행이라고 생각하는데, 입문서랍시고 본 책이 어려우면 그 내용 자체에 거부감을 느끼기 마련인데 이 책을 보니 파이썬에 대해 더 공부하고 싶어졌다.\n파이썬 초보라면, 코딩 초보라면 점프투파이썬 완전 추천!\n1. 지쳤다면 잠시 책을 접고 휴식을 취하자\n2. p.67', '2학기 전공필수 과목 중 파이썬으로 프로그래밍을 해야 한다는 내용을 알게 되어 프로그래밍 입문을 위한 도서를 검색하던 중 이 책을 알게 되었습니다. 그리고 여러 책을 비교해보던 중 이 책을 구매하였는데, 이 책을 구매한 가장 큰 이유는 스터디 노트 라는 시스템을 통해 책을 완독할 수 있게 해주었기 때문입니다. 그리고 스터디 노트를 쓰는 공부단 활동을 하면서 책의 내용들을 하나씩 배우다 보니 어느새 파이썬의 기본적인 내용들을 큰 부담 없이 숙지할 수 있게 되었습니다. 다양한 예시와 연습문제를 통해 단순히 문법만을 알려주는 것이 아닌, 파이썬에 있는 여러 가지 부분들의 존재 이유 및 실제 사용방법을 알게 되어 향후 전공 및 프로그래밍에 큰 도움이 될 것 같습니다.\n1. 좋은 글귀, 마음에 드는 가사 인상 깊은 영화 대사 등을 메모해 주세요.\n2. 출처를 넣어주세요. ex) 234page, 4번 트랙<사랑해>, <브리짓존스의 다이어리>에서 브리짓의 대사', ' 그동안 전공 공부를 하면서 Java 위주로 프로그래밍 공부를 했는데 파이썬도 공부해두면 나중에 도움이 될 것 같아서 파이썬 책을 찾아봤다. 천천히 공부해 볼 생각으로 찾다가 Do it! 시리즈 중에 파이썬 입문서가 있어서 골랐다. 책의 분량은 356페이지로 조금 얇은 편이라 적당해 보였다. 내용은 크게 첫째 마당과 둘째 마당으로 나눠서 구성되어 있고 총 7장에 걸쳐서 파이썬 프로그래밍에 대해 소개한다. 그리고 각 장마다 연습문제가 있고 끝에 파이썬 초보 탈출 코딩 면허시험 20제와 연습문제 및 코딩 면허시험의 풀이가 있다.\n   먼저 첫째 마당은 파이썬 기본 문법 익히기로 01장부터 05장까지 파이썬의 기본 문법을 다룬다. 01장 파이썬이란 무엇인가?에서는 파이썬에 대해 간단하게 소개하고 프로그래밍 실습을 위한 파이썬의 개발환경을 설정하는 방법을 설명한다. 02장은 파이썬 프로그래밍의 기초, 자료형으로 파이썬에서 사용하는 자료형에 대해 소개한다. 파이썬에는 다양한 자료형이 있는데 다른 프로그래밍 언어들의 기본 자료형과 비슷한 숫자형 자료형, 문자열 자료형, bool 자료형 그리고 다른 언어에서 배열과 유사한 List 자료형, 파이썬에만 존재하는 Tuple 자료형, Dictionary 자료형과 집합 자료형을 소개한다.\n   이어서 03장 프로그램의 구조를 쌓는다! 제어문에서는 파이썬의 조건문과 반복문을 다룬다. 파이썬의 제어문은 다른 프로그래밍 언어들과 거의 같다. 그래서 조건문으로 if문, 반복문으로 while문과 for문을 설명한다. 04장 프로그램의 입력과 출력은 어떻게 해야 할까?에서는 파이썬으로 프로그램의 입출력을 위한 문법을 다룬다. 함수의 정의와 사용법부터 시작해 사용자의 입출력을 위한 내장함수들 그리고 파일과 관련된 입출력 내장함수까지 설명한다. 05장은 파이썬 날개 달기로 파이썬의 객체지향과 관련된 문법을 다룬다. 객체지향에서 중요한 Class와 객체의 개념을 설명하고 이어서 Module과 Package로 점점 범위를 넓혀가며 소개한다. 그리고 예외처리와 내장함수, 파이썬 Library를 알아본다.\n   다음으로 둘째 마당은 파이썬 실력 키우기로 앞서 공부한 파이썬 기본 문법을 바탕으로 06장과 07장에 걸쳐 기초적인 프로그래밍을 실습해 보는 것을 다룬다. 06장은 파이썬 프로그래밍, 어떻게 시작해야 할까?에서는 앞으로 본격적인 프로그래밍을 할 때 도움이 될 수 있는 기초적인 프로그래밍을 몇 개의 예제로 실습해본다. 07장은 정규 표현식으로 정규 표현식의 정의부터 메타 문자의 종류들을 소개하고 정규 표현식의 사용을 위한 re Module을 소개한다.\n   파이썬을 1학년 때 교양필수 과목으로 공부해본 적이 있긴 한데 이 때는 객체지향개념 전까지 기초부분만 다뤄서 끝까지 다 배웠다고 하기에는 애매했다. 그래서 다시 처음부터 공부한다는 생각으로 이 책을 골랐는데 파이썬 문법에 대해 처음부터 난이도를 깊게 들어가지 않고 그림과 예시 코드를 같이 보여주면서 설명을 쉽고 자세하게 해주니 금방 이해가 되었다. 또한 저자의 동영상 강의도 같이 소개되어 있어서 독학하는 사람들에게 도움이 될 것 같다. 그리고 각 장마다 너무 어렵지 않게 적당한 난이도의 연습문제와 마지막에 코딩 면허시험 문제까지 있기 때문에 혼자 코딩 실습해보면서 문제를 풀어보는데 충분한 것 같다.']
# <ipython-input-13-b7459bc2bbe0>:24: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   linkNum=driver.find_element_by_css_selector(linkurl)
# <ipython-input-13-b7459bc2bbe0>:27: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   readLinks=driver.find_elements_by_css_selector('#infoset_reviewContentList div.reviewInfoBot.crop > a')
# <ipython-input-13-b7459bc2bbe0>:32: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   review_list=driver.find_elements_by_css_selector('#infoset_reviewContentList div.reviewInfoBot.origin > div.review_cont')
# <ipython-input-13-b7459bc2bbe0>:45: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   linkNext=driver.find_element_by_css_selector(nextBlock)

# %%
for item in temp_list:
    print(item)
# Out:
# 박응용님의 <Do it! 점프 투 파이썬> 리뷰입니다.
# 파이썬을 처음 접하면서 베스트셀러에 있는 책을 구매하게되었는데요.
# 설명이 굉장히 쉽게 되어있고 온라인 강의도 포함되어 있는 것 같아서 좋았습니다.
# 온라인 강의는 들어보진 않았지만 책으로도 충분히 이해가 되어 만족스러웠습니다.!!!
# 개념을 확실히 이해하기 좋은 책인 것 같도 다른 시리즈들은 실습하기 좋은 것 같더라고요 ~~
#
# 정말 파이썬의 기본적인 문법을 알기에 좋아요
# 또한 다른 언어랑도 비교 및 객체에 대해서 잘 설명해주고
#   언어가 어떻게 돌아가는지 등에 대해서도 잘 알려주기 때문에 언어의 입문으로는 정말 좋다고 생각합니다.
# 기본적인 언어에 대해서는 정말 잘 설명되어있고 그외에 간단한 응용은 잘 설명이 되어있습니다.
#   하지만 심화 과정은 그리 깊게 들어있지않아 이 책 하나로 끝내기는 어렵습니다.
#   다만 심화과정은 따로 책을 구비하셔야 합니다.
#
# 모든 입문서가 이 책은 초보라도 할 수 있다고 말하지만 이 책은 정말로 초보도 할 수 있을 정도로 상세하고 친절하게 처음부터 알려준다. 개인적으로 이 책으로 파이썬 공부를 시작하게 되어서 정말 다행이라고 생각하는데, 입문서랍시고 본 책이 어려우면 그 내용 자체에 거부감을 느끼기 마련인데 이 책을 보니 파이썬에 대해 더 공부하고 싶어졌다.
# 파이썬 초보라면, 코딩 초보라면 점프투파이썬 완전 추천!
# 1. 지쳤다면 잠시 책을 접고 휴식을 취하자
# 2. p.67
# 2학기 전공필수 과목 중 파이썬으로 프로그래밍을 해야 한다는 내용을 알게 되어 프로그래밍 입문을 위한 도서를 검색하던 중 이 책을 알게 되었습니다. 그리고 여러 책을 비교해보던 중 이 책을 구매하였는데, 이 책을 구매한 가장 큰 이유는 스터디 노트 라는 시스템을 통해 책을 완독할 수 있게 해주었기 때문입니다. 그리고 스터디 노트를 쓰는 공부단 활동을 하면서 책의 내용들을 하나씩 배우다 보니 어느새 파이썬의 기본적인 내용들을 큰 부담 없이 숙지할 수 있게 되었습니다. 다양한 예시와 연습문제를 통해 단순히 문법만을 알려주는 것이 아닌, 파이썬에 있는 여러 가지 부분들의 존재 이유 및 실제 사용방법을 알게 되어 향후 전공 및 프로그래밍에 큰 도움이 될 것 같습니다.
# 1. 좋은 글귀, 마음에 드는 가사 인상 깊은 영화 대사 등을 메모해 주세요.
# 2. 출처를 넣어주세요. ex) 234page, 4번 트랙<사랑해>, <브리짓존스의 다이어리>에서 브리짓의 대사
#  그동안 전공 공부를 하면서 Java 위주로 프로그래밍 공부를 했는데 파이썬도 공부해두면 나중에 도움이 될 것 같아서 파이썬 책을 찾아봤다. 천천히 공부해 볼 생각으로 찾다가 Do it! 시리즈 중에 파이썬 입문서가 있어서 골랐다. 책의 분량은 356페이지로 조금 얇은 편이라 적당해 보였다. 내용은 크게 첫째 마당과 둘째 마당으로 나눠서 구성되어 있고 총 7장에 걸쳐서 파이썬 프로그래밍에 대해 소개한다. 그리고 각 장마다 연습문제가 있고 끝에 파이썬 초보 탈출 코딩 면허시험 20제와 연습문제 및 코딩 면허시험의 풀이가 있다.
#    먼저 첫째 마당은 파이썬 기본 문법 익히기로 01장부터 05장까지 파이썬의 기본 문법을 다룬다. 01장 파이썬이란 무엇인가?에서는 파이썬에 대해 간단하게 소개하고 프로그래밍 실습을 위한 파이썬의 개발환경을 설정하는 방법을 설명한다. 02장은 파이썬 프로그래밍의 기초, 자료형으로 파이썬에서 사용하는 자료형에 대해 소개한다. 파이썬에는 다양한 자료형이 있는데 다른 프로그래밍 언어들의 기본 자료형과 비슷한 숫자형 자료형, 문자열 자료형, bool 자료형 그리고 다른 언어에서 배열과 유사한 List 자료형, 파이썬에만 존재하는 Tuple 자료형, Dictionary 자료형과 집합 자료형을 소개한다.
#    이어서 03장 프로그램의 구조를 쌓는다! 제어문에서는 파이썬의 조건문과 반복문을 다룬다. 파이썬의 제어문은 다른 프로그래밍 언어들과 거의 같다. 그래서 조건문으로 if문, 반복문으로 while문과 for문을 설명한다. 04장 프로그램의 입력과 출력은 어떻게 해야 할까?에서는 파이썬으로 프로그램의 입출력을 위한 문법을 다룬다. 함수의 정의와 사용법부터 시작해 사용자의 입출력을 위한 내장함수들 그리고 파일과 관련된 입출력 내장함수까지 설명한다. 05장은 파이썬 날개 달기로 파이썬의 객체지향과 관련된 문법을 다룬다. 객체지향에서 중요한 Class와 객체의 개념을 설명하고 이어서 Module과 Package로 점점 범위를 넓혀가며 소개한다. 그리고 예외처리와 내장함수, 파이썬 Library를 알아본다.
#    다음으로 둘째 마당은 파이썬 실력 키우기로 앞서 공부한 파이썬 기본 문법을 바탕으로 06장과 07장에 걸쳐 기초적인 프로그래밍을 실습해 보는 것을 다룬다. 06장은 파이썬 프로그래밍, 어떻게 시작해야 할까?에서는 앞으로 본격적인 프로그래밍을 할 때 도움이 될 수 있는 기초적인 프로그래밍을 몇 개의 예제로 실습해본다. 07장은 정규 표현식으로 정규 표현식의 정의부터 메타 문자의 종류들을 소개하고 정규 표현식의 사용을 위한 re Module을 소개한다.
#    파이썬을 1학년 때 교양필수 과목으로 공부해본 적이 있긴 한데 이 때는 객체지향개념 전까지 기초부분만 다뤄서 끝까지 다 배웠다고 하기에는 애매했다. 그래서 다시 처음부터 공부한다는 생각으로 이 책을 골랐는데 파이썬 문법에 대해 처음부터 난이도를 깊게 들어가지 않고 그림과 예시 코드를 같이 보여주면서 설명을 쉽고 자세하게 해주니 금방 이해가 되었다. 또한 저자의 동영상 강의도 같이 소개되어 있어서 독학하는 사람들에게 도움이 될 것 같다. 그리고 각 장마다 너무 어렵지 않게 적당한 난이도의 연습문제와 마지막에 코딩 면허시험 문제까지 있기 때문에 혼자 코딩 실습해보면서 문제를 풀어보는데 충분한 것 같다.
# 파이썬에 대해 공부해보고 싶어서 이것저것 찾아보다가 이 책을 구매하게 되었습니다. 입문용으로 좋고 처음 접하시는 분들이 흥미와 재미를 느낄 수 있는 책인 거 같습니다. 그리고 연습문제를 풀어 볼 수 있고 연습문제를 통해 잘 모르는 부분을 한 번 더 짚고 넘어갈 수 있어서 좋았습니다. 파이썬이 아직은 어렵지만 저처럼 파이썬을 처음 접하시는 분들께 추천드립니다.
# 인터넷에서 무료로 봤던 내용입니다만,
# 지인 선물용으로 하나 구매했습니다.
# 인터넷에 비해 내용이 조금더 이해하기 쉽게 바뀌고,
# 역시 책자이다보니 구성이 좀더 좋네요.
# 입문용으로는 사실상 원픽이라고 보셔도 되겠네요.
# 요즘 인터넷에도 좋은 강좌가 많이 있지만,
# 활자로 공부하는걸 선호하시는 분들께는 최고의 선택이 아닐까 싶습니다.
# 파이썬이 컴퓨터 언어 중에 가장 배우기 쉽다는 의견이 많아서, 파이썬을 배워보아야 겠다는 생각을 했었습니다. 요즘엔 인터넷 강의. 학원 등 다양한 방법이 있지만, 이런건 혼자 독학하는 것을 선호해서 책을 찾아보게 되었고, 결국 이 책을 알게 되었습니다. 맥북을 사용해서 진행하느라고, 중간에 한번 움찔했지만, 그 다음부터는 문제없이 착착 해낼 수 있었습니다. 가장 기본을 공부하기에 좋은 책이라 생각합니다.
# 이 리뷰는 2019년 06월 이지스퍼블리싱 출판사에서 출간된 박응용 작가님의 Do it! 점프 투 파이썬을 읽고 작성되었습니다. 다른 언어는 모두 배워봤지만 파이썬만은 따로 배운 적이 없어서 기본부터 배우고자 기본서로 유명한 이 책을 선택했습니다. 파이썬의 기초부터 세세하게 다루는 책이라 초보자도 쉽게 이해할 수 있어서 좋았으며 중간중간 이해를 위한 그림 또한 보는데 거슬리지 않아서 좋았습니다.
# 프로그래밍을 처음 접하는 사람이 공부하기에 좋은 책이다.
#   그리고 기존에 JAVA, C, C++, C#등의 언어로 개발한 경력이 있는 분들은 빠르게 이책을 읽고
# tkinter나 flask를 활용하여, 콘솔기반이나 웹기반으로 책에 있는 예제를 실습해 나가면 빠르게 파이썬에 친숙해질 수 있다.
#   특히 마지막장엔 모든 개발자들이 자주 쓰지만 익숙해지기 어려운 정규표현식의 내용을 담고 있어서 파이썬을 주력언어가 아닌 두번째 메인언어로 삼고자 하는 분들에게도 팁이 되는 책이다.
#
# 프론트엔드 개발 직군으로 취업 준비중입니다. 보다 나은 경쟁력을 갖추기 위해서 백엔드 영역에 대한 추가적인 공부의 필요성을 느꼈고 그래서 선택한 언어가 파이썬입니다. 다른 프로그래밍 언어와 비교한다면 확실히 파이썬은 간결한 언어입니다. 강력한 내장 함수들의 도움으로 어느 누구든 비교적 쉽게 접근하고 공부할 수 있는 언어입니다. 교재 자체도 파이썬의 정석이라고 부를 수 있을만큼 군더더기 없이 깔끔한 구성이라 공부하는 내내 크게 불편한 점 없이 완독할 수 있었습니다. 다만 한가지 아쉬운 점을 꼽자면 책의 후반부로 갈수록 설명이 아닌 단순하게 정보만 전달하는듯한 구성을 보여서 살짝 아쉬움을 느꼈습니다.
# 동생이 컴퓨터공학과라 필요하다고 해서 하나 사줬어요!!!
# 문과인 저는 파이썬이 뭔지 하나도 모르지만ㅎㅎㅎㅎ동생이 여러 책 다 비교해보고 이게 젤 잘 정리 되어 있고, 보기 깔끔해서 이걸로 구매했는데 평이 좋네요!!!
# 책 표지도 깔끔하고, 안에 내용도 잘 정리되어 있는 것 같더라구요. 앞으로 배울 과목이 많은데 이 시리즈 책만 사야겠어요!!!
# R 이외에서 프로그래밍 언어를 공부해야겠다는 다짐을 했습니다. 그래서 파이썬에 관심이 갔는데요, 책을 완독한 후에 파이썬에 대한 기초 문법을 어느정도 잡았다는 생각이 들었습니다. 덕분에 파이썬을 더 알고싶다는 생각도 들었고 학교수업도 잘 따라가고 있습니다!
# 다음에는 파이썬 생활 프로그래밍에 대해서도 공부하고 싶습니다. 그리고 케글데이터를 이용한 데이터분석과 머신러닝을 만들어 보고싶습니다. 저에게 이런 동기부여를 주셔서 정말 감사합니다.
# 파이썬이라는 언어의 기본기를 탄탄히 다질 수 있는 교재라고 생각합니다.
# 특히, 파이썬을 사용하다가 헷갈리는 부분이 생겼을 때 빠르게 검색해서 (e-북 사용) 내용을 확인할 수 있어서 좋았고
# 목차도 활용하기 쉽게 잘 나누어져 있다는 것을 느꼈습니다.
# 혼자 공부했으면 지지부지 끌다가 중간에 그만 뒀을텐데, 스터디 노트를 작성해야 한다는 의무감이 생기니
# 독학을 해도 끝까지 책을 완독할 수 있었습니다.
# 파이썬 자료형부터 제어문, 반복문, 실제 프로그래밍 예제, 마지막 부분에서는 자연어 처리를 위한 정규 표현식까지 전반적으로 다루고 있습니다. 기초를 다지고 심화 학습을 시작하기 전 단계로 매우 훌륭한 기본서입니다. 역시 사람들이 많이 보는 데에는 이유가 있습니다! 아주아주아주 추천합니다~! 앞으로도 책장에 꽂아 두고, 막힐 때마다 펼쳐볼 것 같습니다. 다들 고민말고 구입하세요!
# 유튜브를 보다가 요새 코딩에 대해 얘기가 많더라구요.
# 그러다가 관심이 생겨서 이것 저것 알아봤어요.
# 파이썬이 제일 배우기 쉽다고 해서 그럼 공부 한번 해볼까 싶었어요.
# 그래서 파이썬 관련된 책을 찾다가 이 책이 베스트셀러에 동영상 강의를 제공해주길레 구매해봣어요. 그리고 조코딩님도 추천하는 것 같아서 구매했는데 구성이 깔끔하고 보기 쉬워서 좋았습니다.
# 엶심히 해서 관련된 다른 책들도 섭렵해봤으면 좋겠네요.
# 입문서 1위 답게 초보자의 눈높이에 맞춘 탄탄한 책이다. 독학을 하며 가장 힘든게 커리큘럼을 파악하는 것인데 이 책은 목록에 따른 진도표를 제시해서 개인별로 목표를 잡고 공부할 수 있게 도와준다. 또한 이 책을 끝마치면 봐야 할 다음 책도 준비 되어 있고 시리즈별로 정리가 잘 되어 있다. 유튜브 강의도 무료 제공이지만 책만 보고서도 수월하게 따라갈 수 있다. 첫 단원에서 초보라면 모를 수 있지만 어디에 물어보기 애매한 부분(에디터, 주석문, 줄바꿈 등)도 다 설명 되어 있다.
# 박응용 작가님이 집필하신 [Do it! 점프 투 파이썬]의 리뷰입니다. 요즘 하도 코딩교육이다 알고리즘이다 4차 산업혁명이다 말은 많은데, 정작 프로그램의 프 자도 모르는 인간이라 뭐라도 배워둬야겠다 싶어 구매하게 된 책입니다. 파이썬 입문서로 많이들 추천하시더라고요. 솔직히 어떤 부분에서는 너무 초보용이라 불필요하게 쉬운 말로 표현하려다 보니 좀 아리송해지는 부분들이 있기는 했습니다만, 오래전 학교 과제 때문에 구매했던 C입문서에 비해서는 훨씬 유익하게 볼 수 있는 책이었어요. 저 역시 누군가에게 입문서로 이 책을 추천할 것 같기는 하네요. 잘 배워갑니다.
# 이지스퍼블리싱의 "Do it" 시리즈는 기술 입문용 도서 시리즈로 어떤 책을 구매하든 해당 기술에 쉽게 입문할 수 있도록 가이드해 주는 책이라고 생각하시면 될 것 같습니다. 저는 "Do it 딥러닝 입문" 도서와 "Do it 점프 투 파이썬" 도서를 구매하여 읽어 보았는데요. 두 도서 모두 어려움 없이 만족스럽게 읽을 수 있었습니다. 다만, "Do it 점프 투 파이썬" 도서의 경우에는 파이썬 기본 문법을 빠르게 훑어보고 익히기에는 좋으나, 프로그래밍 경험이 전혀 없는 분이 프로그래밍의 개념을 이해하기에는 부족한 부족한 부분이 있습니다.
#   파이썬은 개발 언어에서도 제일 쉬운 언어 중에 하나이다. 그래서 비전공자라 하더라도 비교적 쉽게 언어를 배울 수가 있다. 지금 세계에서 가장 각광을 받고 전망이 좋은 언어이기도 하다. 구글에서 만들어진 소프트웨어의 50% 이상이 파이썬으로 만들어진 것만 봐도 그 이유를 알 수 있다.
# '파이썬'은 인간다운 언어이다.
# 나는 개발자로 일한지가 벌써 17년이 되었다. 내가 할 수 있는 언어는 상당히 많은 편이다. 이것을 IT 분야에서는 '풀스택 개발자'라고 말한다. JAVA를 주언어로 사용하고, JSP, ASP, PHP, Javascript(JQuery,AnglerJS) 등 프런트 엔드와 백 엔드를 동시에 할 수 있다. 데이터베이스는 RDBMS(관계형 데이터베이스) Oracle, Mssql, MySql을 다룰 줄 알고, NoSql은 몽고디비를 사용 가능하다. 그리고 C와 C++도 배운 적이 있다. 파이썬은 매우 흥미가 있는 언어라 책을 가지고 있는 중이다.
#   이처럼 수많은 개발 언어가 있는데, 다른 언어에 비해 '파이썬'은 사람이 생각하는 방식을 그대로 풀어서 표현할 수 있는 언어에 가깝다. 유연한 언어라고 보면 된다. 간결한 언어이기 때문에 소스 문법조차 잘 정돈된다. 그래서 문법이 쉬워서 빠르게 습득이 가능하다. 또 무료이지만 아주 강력하다. 대부분의 시스템을 파이썬으로 개발이 다 가능하단 얘기다. 단, 엄청난 횟수의 반복과 연산이 필요한 프로그램과 모바일 프로그램은 어렵다.
# "Life is too short, You need Python" (인생은 너무 짧으니 파이썬이 필요해.)
# 파이썬의 엄청나게 빠른 개발 속도를 두고 유행처럼 퍼진 말이다. 이처럼 파이썬은 개발 속도가 빠르다.
# 저자인 '박응용'은 국내 파이썬의 선구자 격인 사람으로 '위키독스'라는 서비스 사이트를 제작하여 관련 지식을 알리는데 힘을 쓰고 있다. '코딩 도장'이라는 알고리즘을 테스트하고 수련하는 사이트도 운영 중이다. 이 책은 파이썬의 기본을 다지기엔 아주 좋은 책이다. If, For 문과 변수의 개념만 이해한다면 누구나 쉽게 파이썬으로 프로그램의 세계에 입문할 수 있다.
# 처음에는 쉽다고 느껴졌는데 뒤로 갈수록 생각보다 어려웠습니다. 그러나 유튜브 강의가 있어서 이해하지 못했던 부분도 넘길수 있었습니다. 아직 이러한 실력으로 어떤 프로그램을 짜야하는 건지 어리둥절하지만 2, 3회독을 하여 실력을 많이 쌓고싶습니다.
# 기본기를 익히고 싶어하시는 분들에게 좋은 책이어서,
# 처음 파이썬하시는 분들에게도 추천합니다!
# 내가 봐왔던 다른 일반적인 파이썬 책들은
# 프로그래밍을 처음 시작하는 사람들을 위주로 하였기 때문에
# 약간 어려울 수 있는 내용은 모두 배제하고 설명이 많았다면,
# 이 책은 다른 책에 비해 깊이가 있게 파이썬에 대해 다루고 있다.
#   특히, 내가 이 책을 선택하게 된 결정적인 이유는
# 05장의 5.내장함수와 6.라이브러리 부분이다.
# 아마, 이 책이 아니었다면 접하기 어려웠을 수도 있는 다양한 내용들을 포함하고 있어
# 개인적으로 저자에게 감사의 말씀을 전한다.
#   단점이라면 단점일 수 있는 것은 설명이 약간은 부족할 수 있어
# 프로그래밍을 아예 처음부터 배우는 사람에게는 멘토나 선생님이 필요하지 않을까 싶다.
# 현재 나 또한 아이들에게 이 책을 교재로 하여 파이썬을 가르치고 있다.
# 굳이 이 책을 교재로 선정하게 된 이유는 나중에 또 보게 될 가능성이 높다는 생각에서였다.
# 그만큼 소장가치가 있다는 얘기다.  (나는 저자와 일면식도 없는 사람임..^^)
# 파이썬하면 점프 투 파이썬이라고 하여 주문했습니다. 인터넷으로도 책의 내용을 지원하는데 직접 책으로 보는 것이 공부하기도 편할 것 같고 기본서 하나는 있어야 할 것같아 구매했습니다. 파이썬 설치 방법부터 기본 문법까지 정말 예시도 다양하고 심화 내용으로 모듈 패키지 내용까지 다루고 있어 이 책 한권만 완벽하게 해도 파이썬 마스터 할 수 있을 것 같습니다!!
#
#
# 우선 가독성이 좋아서 공부하기가 편했다. 공부하다가 궁금한 부분이 생기면 거기에 대한 설명도 거의 다 옆에 실려있어서 책 표지의 '14년 내공'이라는 것이 이거구나 싶었다. 이정도면 예제도 충분히 많은 것 같고, 책으로 잘 이해가 안되는 부분은 유튜브 강의로 해결할 수 있어서 좋았다. 전체적으로 파이썬 기본 다지기에는 부족함이 없는 책이다. 파이썬은 처음이라 책을 뭘 살지 많이 고민했었는데 잘 산 것 같다!
#  저는 파이썬에 대해서 1도 몰랐던 사람인데 이 책을 통해서 파이썬에 대해서 아주 기초적인 것들 부터 응용하는 법까지 넓은 스펙트럼을 공부할 수 있었습니다. 특히 독학을 하기에 너무 좋은 책이었습니다.
#  유튜브 강의가 제공 되기 때문에, 파이썬을 전혀 모르는 저 같은 사람들도 영상을 보고 하나씩 따라하면서 진도를 나갈 수 있었습니다.
#  책의 구성도 중요한 부분들 위주의 설명, 이후 예제 학습 순이어서 책만을 활용해서 공부를  하기에도 큰 무리가 없다고 느껴졌습니다.
#  빅데이터, 코딩의 중요성이 급부상된 요즘 뒤쳐지고 싶지 않아서 코딩 공부 독학을 시작하고 싶으신 분들께 추천합니다~!
# 파이썬에 대한 기본적인 개념을 차근차근 확실하게 정리할 수 있습니다. 책 표지에 나와있는 것처럼 정말 누구나 이해할 수 있습니다. 파이썬, 그리고 프로그래밍을 처음 접하는 초보자분들께 걱정하지 말고 이 책을 선택하시라고 말씀드리고 싶습니다!! 책 내용이 정말 기본적인 것부터 자세하게 가르쳐주기 때문에 충분히 이해할 수 있고 심지어 유튜브에서 무료 강의도 찾아볼 수 있기 때문에 혼자서 공부하기에 어려움이 없습니다. 혼자서 처음 시작해보려고 하는 분들께 정말 강력추천합니다
# Do it! 첫 파이썬에 이어서 [Do it! 점프 투 파이썬]을 독학으로 거의 3주만에 독파했다.. 유투브나 이지스퍼블리싱에 동영상 강의도 함께 있어서, 책으로 보다가 이해가 되지 않는 부분은 동영상을 참고하여 스터디를 진행하였다..
#  이전 책과 다르게 많이 사용하는 키포인트들만 잘 요약하여 정리한 책이란 생각이 들었다.. 처음 4장까지는 별 무리없이 진도가 나갔지만, 클래스에서는 개념이 잘 서지 않아 보고, 다시 보고를 여러 번 했다.. 교재에 있는 여러 예제들을 따라 하며, 활용부분에서 조금씩 이해도를 높여 나갔다.. 다양한 색의 형광펜을 준비하여 꼭 알아야 할 내용과 기억이 잘 나지 않는 부분은 별도 체크를 하며 진행하였고, 중간중간 구성되어 있는 나혼자 코딩 예제나 매 챕터 마지막의 연습문제들로 나의 이해도를 체크했고, 풀지 못한 예제는 앞으로 다시 돌아가 문법정리를 했다.
#  개념은 이해했는데, 막상 간단한 프로젝트에서는 뭐부터 시작해야 할지 몰라 헤매기도 했다.. 코딩 실전에서 프로그램을 만들기 위해 필요한 입력값, 결과값, 필요한 기능 등을 정리한 표와 함께 시작하니 좀 더 윤곽이 잡히는 것 같다..
# 1독으로는 부족해서 다시 클래스 부분만 더 보기로 했다..
# 6장의 실전 미니 프로그램에서는 아래와 같이 파일 내에 하나를 끝내면 코멘트 처리하고 그다음 예제를 계속 더하면서 한 파일로 만들었다^^..
# 2회독을 하면 좀 더 파이썬의 개념이 명확히 잡힐 것 같은데.. [Do it시리즈]는 독학하기에 구성이 잘 되어 있어서, 시공간에 제약을 받는 사람에게는 권할 만 하다..
# 처음 파이썬 프로그래밍을 시작했을 때 무슨책을 살지 고민했었는데 인터넷을 검색하면서 이 책이 정말 내용도 좋고 괜찮다라는 말을 접해서 구매했는데 후회는 1도 없고 오히려 이 책을 구매하기 너무 잘 한 것 같다
# 덕분에 파이썬 기초문법과 왠만한 프로그램을 거의 다 만들 수 있게 되었다
# 그리고 파이썬 입문책이나 강의에서 잘 다루지 않는 고급 개념까지 나와있어서 매우 만족했다
# 파이썬에 대해 공부하고 싶다면, 파이썬에 대해 어렵지 않게 알고 싶다면 이 책이 답이 아닐까?입문자에게 이해하기 쉽도록 설명되어있고, 구조가 잘 되어있어 혼자서 책을 보며 하기 좋게 되어있다. 유튜브에 무료강의가 올라와있어 어려웠던 부분에서 많은 도움을 받았고, 코딩이라는 자체에 두려움을 느끼고 있었는데 이 책을 통해 파이썬에 대해 알아갔고 앞으로 이 회사 시리즈의 책을 많이 사서 공부 할 것 같다고 생각했습니다.
# Do it! 점프 투 파이썬...파이썬을 시작하기에 보다 알찬...
#   기초부터 어느 정도 응용까지...
# 전반적으로 무난한...
# 물론 전문적인 지식들은 세부로 들어가 각각 전문서적이 필요하지만...
# 기초 또는 기본의 측면에서만 본다면
# 특별한 프로그램에 대한 지식이 부족하거나 전무하여도
# 어렵지 않게 접근하고 전반적인 터치가 이루어진 내용인듯...어디까지나 개인적...
#   총분량은 350페이지가 넘고
# 파이썬 생활프로그래밍보다는 이 책으로 바로 시작하는 것이...개인적으로 추천...
# 입문자에게 도움이 많이 될 듯...
# 비전공자라서 코딩에 대해 전혀 모르는 상태로 전공자인 지인에게 추천받아 이 책으로 공부하기 시작하였다.
# 중요한 부분은 자세히 설명해주고, 이후 그와 관련된 다양한 기능(함수)들을 설명해주며 넘어가기에 기초를 쌓기에도, 나중에 필요한 기능들의 이름이 잘 기억나지 않을 때 사전으로 활용하기에도 좋은 책이라고 생각한다. 적당한 난이도의 연습문제가 있어 배운 내용을 체화하기 좋았다.
# 유튜브에 무료강의가 올라와있어 어려웠던 부분에서 많은 도움을 받았다.
# 이지스퍼블리싱에서 출간한 박응용님 저의 Do it 점프 투 파이썬입니다.
#   Do it 시리즈는 모두가 아시다시피 프로그래밍 언어학습 초심자들의 교과서나 마찬가지이죠
#   파이썬 관련 교재를 여러권 사보았지만 두잇 시리즈만큼 프로그래밍알못인 초심자들에게 친절한 교재도 드물다는 생각이 듭니다.
#   여러 예제를 통해 학습하다보면 파이썬뿐만이 아니라 프로그래밍의 기초적인 부분까지도 학습이 가능한 책이니 꼭 추천드리고 싶습니다.
# 파이썬에 대해 공부하고 싶다면, 파이썬에 대해 어렵지 않게 알고 싶다면 이 책이 답이 아닐까?
# 입문자에게 이해하기 쉽도록 설명되어있고, 구조가 잘 되어있어
# 혼자서 책을 보며 하기 좋게 되어있다.
# 간결하고도 알기쉽게 쓰여있어, 따라하면서 공부하기 참 좋은 책인 것 같다.
# 특히 독학하고 싶다면, 이 책을 추천하고 싶다. 코딩에 대해 알아가기 좋은 책인것 같다.
# 설명이 쉬워서 초보자에게도 좋아요
# 설명이 쉬워서 초보자에게도 좋아요
# 설명이 쉬워서 초보자에게도 좋아요
# 설명이 쉬워서 초보자에게도 좋아요
# 설명이 쉬워서 초보자에게도 좋아요
# 설명이 쉬워서 초보자에게도 좋아요
# 설명이 쉬워서 초보자에게도 좋아요
# 설명이 쉬워서 초보자에게도 좋아요
# 설명이 쉬워서 초보자에게도 좋아요
# 설명이 쉬워서 초보자에게도 좋아요
# 설명이 쉬워서 초보자에게도 좋아요
# 설명이 쉬워서 초보자에게도 좋아요
# 파이썬의 경우 "your life too short, use python"이라는 말에 생산성이 높은 언어였습니다. C와 java를 학습한적이 있었던 점을 감안해도 학습하기가 편했습니다. 저자님과 대화한다고 생각하고 책을 정독해나가며 코드를 따라치면 쉽게 배울수 있는 편집이어서 학습하기 수월했습니다. 다만 챕터마다 시작시 주의를 환기하기위한 명확한 학습목표와, 학습한내용을 개관하는 페이지가 없어서 아쉬웠습니다. 하지만 가성비가 매우 좋은 책입니다. 별 5개만점에 4.5개입니다!
# 데이터 분석 분야로 이직하기위해 최근 파이썬 공부를 시작했습니다. 지인의 추천으로 이 책을 구입하여 매일 공부중입니다. 교재는 이해하기 쉽게 구성되어 있습니다. 저같은 초보자도 반복적으로 읽고 실습하면 이해할 수 있습니다. 유튜브로는 이해가 되지 않는 부분도 꼼꼼이 글로 읽으니 잘 이해가 되었습니다. 책도 얇은 편이라 들고 다니며 카페에서 공부하기도 좋습니다.
# 앞으로 이 책을 바탕으로 Pandas 등을 추가로 공부할 계획입니다. 파이썬을 독학하고 싶은 분 들에게 추천하는 책입니다.
# 코딩기본서로 강력추천!! 코딩에 대해 하나도 모르는 초보자도 쉽게 따라할 수 있는 예제들이 많아 배우는데 큰 어려움이 없었습니다. 4차 혁명시대를 맞이하며 앞으로도 코딩의 중요성은 커져갈 것이며 코딩 공부는 필수라는 얘기를 듣고 한 번 배워볼까? 하고 막연하게 시작했는데 이 책이 생각보다 잘 이끌어주어 공부하는 내내 즐거웠네요. 파이썬 기초를 탄탄하게 잡아주는데 많은 도움이 되었습니다.
# 초보자가 배우기에 좋은 책이에요.
# 책 자체가 두껍지 않아 부담이 없고 내용 중간마다 팁도 있어요.
# 중간, 해당 장이 끝날 때마다 연습문제들이 있어서 배운 내용을 바로 복습할 수 있고
# 주석들이 잘 적혀 있어서 처음 배우는데 어렵지 않게 학습 할 수 있었어요.
# do it 시리즈로 점프 투 파이썬 외에 생활 프로그래밍 책도 있어서 지금 배우는 책과 연결해서
# 학습하는데 좋을 것 같아요.
#  코딩 입문 책으로 이 책을 선택했다. 앞으로 코딩이 더 중요해질 것이라는 생각과 공부할 때 필요하겠다는 생각에서 파이썬 공부를 시작했다. C++도 그렇고 파이썬도 그렇고 항상 기초만 공부하고 적용하지는 못했었는데 이 점이 항상 아쉬웠다. 그래서 시간이 많은 틈을 타서 파이썬 공부를 시작했다.
#  책은 간결하고, 코딩에 대해 잘 모르는 사람이 봐도 이해하기 쉽게 잘 설명되어 있다. 예제의 난이도도 적당하다.  기초 부분은 예시도 자세히 보여주고 이론도 적당히 쓰여있기 때문에 입문자도 쉽게 배울 수 있다.
#  출판사인 이지스퍼블리싱에서 네이버 카페를 운영하고 있는데, 여기서 스터디를 완료하면 책을 하나 더 준다. 스터디도 어렵지 않으니 이 책을 샀다면 스터디도 병행하는 것을 추천한다.
#  독학의 특성 상 며칠 공부를 안하면 더 하기 싫어지는만큼 스터디를 하면서 부지런히 끝내는 게 좋을 것이다. 책 뒷편에는 정규식에 대한 설명도 최대한 이해하기 쉽게 나와있어서 좋았다. 앞으로도 프로그래밍 관련 책은 이지스퍼블리싱에 나온 책들을 많이 이용하게 될 것 같다.
# 가장 인기 있는 도서인만큼 파이썬을 시작하는 사람들에게 많은 도움이 되는 책입니다. 그렇다고 파이썬을 입문하는 사람들만 볼 정도로 쉬운 내용만 있지는 않습니다. 그 이유는 문법을 알려주고 실제 사용될 만한 예제들로 실습할 수 있게 도와주기 때문에 많은 도움이 됩니다. 마지막에는 코딩면허시험도 있어서 생각하고 풀어볼만한 문제들이 많고 앞으로 개발하면서 사용할법한 부분도 꽤 있는 것 같습니다.
# 1. 파이썬의 기초를 학습(자료형, 제어문, 클래스, 모듈, 패키지)
#  - 체계적으로, 책으로 공부 할 수 있어서 집중이 더 잘 됩니다!
# 2. 앞에서 차근차근 학습한 기초를 바탕으로 초보자용 응용문제를 풀며 복습
# - 너무 어렵지 않고, 공부한 것을 되새김질 할 수 있는 적당한 난이도!!
# 3. 정규식
# - 초보자한테는 어렵지만, 그래도 인지는 하면 도움이 많이 됩니다.
#   인터넷에 돌아다니는 정규표현식을 이해할 수 있습니다.
# 4. 연습문제들
# - 확실히 이해력과 응용력이 좋아지는 것 같습니다.
#
# 이를 바탕으로 파이썬의 기초를 잘 잡을 수 있습니다.
# 조금 더 어려운 알고리즘이나 실무에 적용 하는 것에도 도전 할 수 있다는 자신감이 생깁니다.
# 이 책을 통해 파이썬을 처음 접하게 되었는데 내용이 좋아 이해하기 쉽고 파이썬이란게 어떤건지 알고 싶은 사람이나 파이썬을 공부해보고 싶은데 어떤 책으로 공부할지 고민하는 사람에게 매우 좋은 책인 것 같다.  이 책을 다 공부하여 파이썬에 대해 어느정도 알게 된 것 같고 이 책에 만족을 하여 다음에는 do it시리즈의 조금더 난이도가 높은 파이썬 책이나 java,c같은 다른 언어도 공부하고싶다.
# 파이썬이 대세라는 말이 많아서 파이썬을 알아보고 싶어서 이 책을 선택하게 되었다. 총평은 초보자가 접하기 좋은 책이라는 것이다. 아무래도 파이썬에 대해서 깊이 알기는 어려웠지만 쉽게 코딩에 접할 수 있어서 좋았다. 판매량과 리뷰가 많은 이유를 알겠다. 코알못도 충분히 이해할 수 있을 만큼 책이 잘 짜여져 있었다. 이 책을 시작으로 doit 시리즈를 자주 구매할 것 같다.
# 앞쪽에 일정표가 나와있어서 스터디를 하면서 함께 규칙적으로 진행하는 데 도움이 되었습니다.
#
# 저는 우선 정해진 분량을 한번씩 읽어서 대략적으로 흐름을 파악하고, 두번째 읽으면서는 코드를 따라서 치면서 실습과 병행했습니다. 코드가 한번에 길게 뽜악 나오는 게 아니고, 코드의 발전(?)의 흐름을 따라가게 되어있는 것이 초보적인 입장에서 이렇게 기능 하나하나가 추가될 수 있구나를 알게 해줘서 좋았습니다. 단원이 마무리될 때마다 있는 문제들도 한번씩 보고 너어어무 어렵지 않게 스스로 생각해 볼 수 있었습니다.
#
# 파이썬을 처음 하는 분 뿐만 아니라, 깊이는 아니더라도 다른 언어를 해봤어서 대~충 따라는 할 수 있는 정도의 분들도 한번씩 기초부터 쭈욱 읽고 정리해보기에 좋은 것 같습니다 :)
# 파이썬 입문용으로 좋네요! 파이썬 스터디를 하게됐는데 파이썬을 처음부터 공부하자 싶어서 고르게 된 책입니다. 따라하기도 쉽고 내용도 쉽게 설명되어 있어서 혼자 공부하기에도 큰 무리가 없는 책이었어요. 이 책으로 시작하고 조금씩 확장해 나가면 좋을 것 같아요. 구입하고 알았지만 많은 분들이 추천하는 책이더라구요. 그래서 더 잘샀다 싶었어요ㅎㅎㅎ 완전 초보인 분들한테 추천입니다~
# 프로 그램적 사고를 가져 보기위해 검색해 보다가 파이썬이 쉽다는 글들을 보고 점프 투 파이썬 책을 구입하게 되었다.처음이라 먼소린가하는 부분도 있지만 쉽게 쓰여져서 마직막 까지 예제 수행하면서 책을 완독 할수 있었다.  처음이라 익숙하지 않은 기호들과 규칙에 애를 먹다가도 읽다보면 조금씩 이해되고 익숙해짐을 느꼈다. 초보가 보기에 좋은 책이라 생각한다. 온라인 커뮤니티도 잘 되어있어 책을 완독하는데 큰 도움을 받았다,  이 책을 반복해서 읽고 파이선 자격증에 도전하려 한다. 프로 그램 공부하는 사람 모두 화이팅!!
# 금일 329페이지 책걸이를 완료했습니다.
# 읽으면서 들은 생각은...
#
# 작가님과 편집자님이 독자입장에서 그들이 궁금할 사항을 정말 잘 작성해주셨다는 점입니다.
#
# 읽으면서 머릿속에 의문점이 생기면, 바로 다음줄에 작가님이 친절하게 설명해줍니다.
#
# 특히, 가장 감동적이었던 부분은 필요로 의해서 배워야하는부분을 넘어가야 할때는 과감하게 넘어가고
# 뒤에서 다시 알려주시는 부분이 있어 부담없이 읽을 수 있다는 점이었습니다.
#
# 처음 파이썬을 배우는 분, 파이썬을 배우면서 헛갈리는 분들에게 강력추천드립니다.
#
# 더 나아가, do it study room에서 학습과 질문이 가능하고, 실제로 활발히 이루어지기 때문에
# 궁금한사항이 생기면 언제든지 질문할 수 있어
# 최고의 파이썬 입문교재라고 생각이듭니다.
# 처음에 파이썬을 접하게 된 계기는, 데이터 분석을 위한 파이썬 입문 책이여서 제대로 파이썬의 맛을 알 수는 없었습니다. 파이썬의 기초를 제대로 닦기 위해서 파이썬 책을 찾던 중 점프 투 파이썬이 제일 유명했고 위키독스에서 한번 보고 바로 구매하였습니다.
#
# 우선 출판사의 장점으로, 네이버 카페를 통해서 공부단을 지원할 수 있고 스터디 노트 작성으로 의욕을 고취시킬 수 있습니다.
# 점프 투 파이썬 또한 파이썬 설치 부분을 제외한 자료형(리스트, 튜플 등), 함수 등 매우 쉽게 설명이 되어있어 금방 금방 쉽게 넘어 갈 수 있습니다.
# 함수나 클래스 부분부터는 조금 헷갈리고 적용하는데 어려움이 있지만, 그건 어느 프로그래밍 언어든 마찬가지인 단계라고 생각합니다.
#
# 이 책을 한 번만 읽고 파이썬을 모두 다 잘 할수는 없다고 생각하며, 자기가 부족한 부분을 2~3회 정도 다시 정독하고 심화 단계로 넘어가면 좋다고 생각합니다. 파이썬 입문서로는 가장 좋은 책입니다.
# 사실 기대가 컸습니다. 이거 한 권만 통독하면 곧장 파이썬으로 술술 프로그래밍 할 수 있는 줄 알았죠. 그렇게 프로그래밍이 쉬운 거라면, 대한민국 국민이 다 프로그래머이지 않겠습니까? 저처럼 너무 큰 기대를 하시면 안 됩니다. 이 책 한 권 읽었다고 파이썬으로 프로그래밍 바로 할 수 있는 건 아니에요!! N.E.V.E.R!!!
#
# 굉장히 쉽게 쓰여져 있습니다. 그래서 술술 책장이 넘어 갑니다. 파이썬에 처음 진입하는 책으로서 쉬운 것은 굉장한 메리트라고 생각합니다. 쉬워서, 좌절하지 않고 파이썬에 입문할 수 있습니다. 이 책 한권 읽고 내가 바로 파이썬으로 프로그래밍하는 사람 되겠다는 거창한 포부로 이 책을 시작하지는 마세요. 편한 마음가짐으로, 이 책을 통해 내가 파이썬이 대략 무엇인지 알것이다, 같은 가벼운 마음으로 보시면 큰 성취를 안겨줄 책입니다.
# 많은 분들이 찾으시는 파이썬 책이 무엇인가 들여다 보니 바로 이 점프 투 파이썬 책이었습니다.
# 사실 많은 사람이 찾는다고해서 무작정 좋아하는 스타일은 아니었으나, 초심자도 이해하기 쉽고 친절하게 설명해준다는 점에서 많이 끌렸습니다. 실제로 책을 받아보니 초심자를 배려하는 듯한 꼼꼼함이 있었고 이에 제 실력을 향상 시키는데 도움이 많이 되었다고 생각합니다. 물론 책을 1번 보는것으로는 완전히 체득할 수 없기에 반복해서 보아야겠지요. 초심자라면 , 그리고 파이썬을 많이 잊어버리셔서 복습용 책을 찾으신다면 강력 추천드립니다.
# 1. 좋은 글귀, 마음에 드는 가사 인상 깊은 영화 대사 등을 메모해 주세요.
# 2. 출처를 넣어주세요. ex) 234page, 4번 트랙<사랑해>, <브리짓존스의 다이어리>에서 브리짓의 대사
# 점프 투 파이썬으로 파이썬을 처음 접했었는데.
# 처음 입문하는 사람이 잘 이해할 수 있게 풀어놓은 책인거 같다.
# 프로그래밍언어 라는게 어렵게 느껴졌었는데
# 파이썬 입문하는데 큰 도움을 준거 같다.
# 두 잇 책이 왜 유명한지 알겠다.
# 읽어보니까!ㅎㅎ
# 두 잇책 또 읽고 또 읽고 ~~~~
# 해서 프로그래밍을 다~ 알고 싶다.
# 다음 번에도 두잇 책 사야겠다 :)
# 정말로 초보자가 프로그래밍 입문하는게 고민된다면
# 이 책을 추천하고 싶다.!
# 홈페이지에 공부단도 신청할 수 있게 해놔서
# 공부하기에 동기부여도 같이 시켜주는 좋은 출판사 인거 같다.
# 그동안 다양한 언어를 공부해보고자 했었습니다. C언어도 자바도 도전했었지만, 언제나 끝까지 마무리 짓지 못했고, 잘 사용할 수 있는 대표 언어라고 할 수는 없었습니다. 그런데, 파이썬을 만나고 해 볼만 하겠다고 생각해서 도전하게 되었지만, 역시나 책의 선택은 매우 중요했습니다.
# 파이썬 관련 책들은 끝까지 못했습니다. 문제 위주의 책이었기 때문에 문제를 풀다가 지쳤던 것 같습니다. 그런데, 이 책은 차분하게 기초부터 쌓기에 좋았습니다. 어려운 부분은 역시나 어려웠지만, 그런 것은 몇 번 보면 해결이 되는 것이고, 다양한 연습이 필요한데, 이 책으로 기초를 쌓는데는 충분했습니다.
#
# 기초를 쌓기 위한 용도로는 이 책을 추천합니다. 잘 하실 수 있는 분들이라면 이 책은 너무 쉽고 이론의 나열이 될 수도 있습니다. 따라서 자신의 실력이 초급이라면 파이썬과 친해질 수 있는 계기가 될 것으로 생각됩니다.
#
# 이제, 아주 조금은 파이썬과 친해졌네요.
# 프로그래밍을 처음 시작하는 사람에게 기초 개념부터 하나하나 알려주는 친절한 느낌은 아닙니다만... 약간이라도 프로그래밍의 개념을 알고 있는 상태에서 파이썬을 공부한다는 면에서 봤을 때는 좋은 책인 것 같습니다. 다른 책과 비교해보고 산 건 아니라서 다른 책은 어떨지 궁금해지긴 하지만, 어느책이든 선택했으면 믿고 보면 실력이 늘겠지요. 책을 얼른 마스터해서 만들고자 하는 프로그램을 만들어보고 싶습니다.
# 컴퓨터와 관련된 전공은 아니지만 줄곧 컴퓨터 언어에 대한 관심이 있었다. 하지만 막상 배우기에는 아무것도 모르는 초짜라 시작이 힘들었다. 학원을 다니기는 시간적 여유도, 경제적 여유도 없었기 때문에 생각한 것이 독학이었다. <점프 투 파이썬을> 선택한 것은 파이썬과 컴퓨터 언어라는 개념부터 시작해 난이도 있는 파이썬의 활용까지 한권으로 끝낼 수 있기 때문이다.
#
#
#
#
# 컴퓨터 언어를 기존에 알고 있던 사람들은 이 책을 16일 정도에 끝낼 수 있지만, 나는 인터프리터와 프롬프트라는 것이 뭔지도 모르는 초짜 중의 초짜였기 때문에 30일을 목표로 파이썬 공부를 시작했다. 이제 약 2주정도 계획에 맞추어 공부하는 중이다. 2주동안 파이썬을 공부하며, 컴퓨터 언어의 매력에 빠졌다.
#
#
#
# 검은 창이 슬슬 익숙해지고 >>>에 무언가를 입력하고 싶은 욕구가 샘솟는다. 현재는 for을 이용한 여러 조건문들을 배우는 중이다. 가끔 앞의 것이 헷갈려 모르는 부분을 다시 공부하기도 하고 줄 맞추기를 제대로 하지 못해서 에러가 뜨고 헤메는 경우가 종종 있었지만 그래도 재밌다. 이미 시중에 좋은 계산기나 프로그램들이 있겠지만 파이썬에게는 또다른 매력이 있다. 이미 있는 프로그램들이 이미 완성된 레고와 같다면 파이썬은 마치 수많은 레고 조각들과 같다. 수많은 조각들을 설계에 맞춰 조합하고 원하는 레고모형을 만들수 있는 것이 레고의 매력인 것처럼 파이썬도 잘 응용한다면 내가 원하는 값을 제대로 도출해 낼 수 있다.
#
# 이 책은 단어의 개념과 활용, 파이썬의 상세한 예시들과 함께 추가적인 설명을 덧붙여 파이썬을 쉽고 재밌고 자세하게 배울 수 있는 장점이 있다. 특히 예제들을 따라하며 의미를 파악하는 것이 재미있고 직접 실습해보며 배울 수 있다는 것이 큰 장점이다.
#
# 초보자들이 빠르고 쉽게 파이썬을 배우고 싶다면 이 책을 강추한다. 이유는 다음과 같다.
# 1. 설치부터 파이썬 개념까지 완전 기초적인 것들도 상세히 알려준다.
# 2. 간단하다
# 3. 예제가 많다.
# 4. 단어 설명이 상세하다.
# 회사 업무를 하며 프로그래밍을 배우게 되었는데요. 제가 이제까지 사용했던 언어는 주로 Java, Javascript 등이었습니다. 하지만 요즘 많은 주목을 받고 있는 언어가 파이썬인만큼 언젠가 한번 공부해보고 싶다는 생각을 했어요. 그러던 중에 파이썬 공부에 아주 적합한 책을 알게되어 읽기 시작했습니다.
#
# 프로그래밍 언어는 기계가 이해할 수 있는 문법으로 프로그램을 작성해야 원하는 결과가 도출되죠. 프로그래밍을 처음 접하는 분 중에 이 문법을 어려워하는 분들이 있습니다. 또 언어마다 문법이 조금씩 다르기도 합니다. 파이썬의 장점은 문법이 매우 간결하다는 것이죠. 사람처럼 직관적으로 작성할 수 있다는게 초보자들에게는 아주 유용합니다. 또 C/C++ 등의 언어와 결합도 가능하며 웹 프로그래밍 등에도 자주 사용됩니다. 다만 엄청난 반복과 연산이 필요한 프로그램과 모바일 프로그래밍에는 적합하지 않다는 단점도 있죠. 하지만 이런 단점들을 상쇄할만큼 장점이 많은 언어입니다.
#
# 파이썬에 대한 소개 이후 파이선의 문법들을 본격적으로 설명하고 있습니다. 다른 언어와 비슷하게 파이썬도 숫자형, 문자열 자료형, 리스트 자료형 등이 있습니다. 문자열 자료형에서는 인덱싱과 슬라이싱을 통해 원하는 문자열을 만들어 내는 방법들을 상세히 설명합니다. 또 프로그래밍에 필수적인 제어문도 소개합니다. if문, while문, for문을 통해 특정 조건을 만족하거나 일정 횟수만큼 프로그램을 실행시킬 수 있습니다. 그외에도 클래스와 모듈, 예외처리, 함수에 대한 설명도 자세히 나와있습니다.
#
# 책의 소개에도 나와있지만 이 책의 대상은 파이썬 언어를 처음 접하거나 프로그래밍 언어를 한번도 접해보지 못한 사람입니다. 최대한 전문 용어를 자제하고 이해하기 쉽게 설명하고 있어 초보자들에게 유용합니다. 또 다른 프로그래밍 언어를 공부해본 분이라면 문법 자체를 이해하는데는 크게 어려움이 없으실 거에요. 다만 파이썬을 능숙하게 사용할 수 있을 만큼 반복학습이 필요하겠죠? 이 책을 기반으로 파이썬을 열심히 공부해봐야겠네요. 잘 봤습니다.
# 파이썬을 처음 시작하는 사람들에게 프로그래밍이라는 진입장벽을 낮춰 줄 수 있는 기본 입문서라고 할 수 있다.
# 프로그래밍 언어에는 자바, C++, C 등 용도에 따라 여러 종류가 있는데 그 중에서 파이썬은 프로그래밍의 세계에 첫 발을 담그는 사람들에게 많이 추천하는 언어이다. 그만큼 기초 문법이 쉽고 프로그래밍의 기본이 되는 핵심 개념들을 손쉽게 다룰 수 있기 때문이다.
# 파이썬 하면 가장 최근에 화제가 된 언어라고 생각하기 쉽다. 그렇지만 역사도 오래 되었고 빅데이터 시대에 맞물려 여러가지 기계 학습을 잘 적용할 수 있는 언어이기도 하다.
# 이 책은 가장 먼저, 파이썬의 기본적인 문법에 다루며 2개의 장을 통해 실력을 더 향상 시킬 수 있는 방법에 대해 소개하고 있다.
# 기본 문법의 경우, 파이썬의 특징, 설치, 실행을 1장에 걸쳐 설명하며 왜 우리가 파이썬을 배워야 하는지를 알려주고 데이터를 다루는데 가장 중요한, 여러 가지 자료형들에 대해 순차적으로 설명하고 있다. 각 자료형은 만드는 방법부터 인덱싱, 연산, 삭제 등까지 하나씩 예제를 통해 직접 실습을 할 수 있도록 돕고, 상황에 따라 다르게 처리할 수 있도록 돕는 제어문을 그 다음으로 언급하며 천천히 자신의 실력을 쌓을 수 있도록 이끌고 있다.
# 이 책의 가장 큰 장점은 어렵다고 생각되는 부분을 쉽게 풀어써서, 학습에 지루함을 덜어주는 점이라고 생각한다. 파이썬을 처음 배웠을 때 이 책으로 입문했던 만큼 기초 실력을 탄탄히 기르고 싶은 사람들에게 매우 추천하고 싶은 책이다.
# 전면 개정판 답게 이해하기 어려운 부분은 쉽고 간단하게, 핵심 내용을 위주로 다뤘기 때문에 프로그래밍이라는 어려운 분야에 자신감을 가지고 도전할 수 있도록 만들어 줄 것이다.
# 기계공학 분야 해석을 위해 코딩을 하지만 주로 사용하는 언어가 Fortran이고 C언어나 C++는 공부를 했어도 코딩 시 활용하지 않다보니 실력이 늘지않아 새로운 컴퓨터 언어를 공부를 시작하는 것은 엄두도 못 내왔다. 하지만 이제 주위 사람들 중에도 파이썬을 공부하는 사람이 많이 늘어나서 이제는 더 이상 머물 수 없다는 생각으로 회사 교육 프로그램을 이용하여 파이썬을 공부하였는데, 기존의 프로그래밍 언어에 비해 자연dㅓ에 가까와서 정말 잘 설계된 언어라는 생각이 들었다. 다만 당시 사용한 교재가 파이썬 이외의 외부 데이터 베이스나 웹 프로그랭 퉁을 활용하는 내용이 많아 파이썬에 집중하지 못했던 것이 무척 아쉬웠다. 그러던 중 국내 파이썬 최교 교재로 불리는 점프 투 파이썬을 접하게 되어 무척 좋은 기회라 생각되었다.
#
# 이 책은 파이썬 언어 자체에 집중하여 알차게 공부할 수 있게 만들어진 것이 가장 큰 장점이라고 생각된다. 파이썬에서 가장 중요한 것은 파이썬만의 독특한 자료형을 이해하는 것이라고 보는데, 이 책은 2장에서 80여 펭지를 할애하여 자료형을 설명하여 기초를 탄탄하게 해주는 것이 큰 장점이라고 생각한다. 다음 고비는 아무래도 클래스, 모듈 등을 이해하는 것인데, 역시 80여 페이지를 들여 충실하게 설명하고 공부하게 해주고 있다. 마지막에 나오는 프로그래밍 예제가 그리 목잡하지 않아 누구나 어렵지 않게 공부할 수 있을 것이라 보는데, 갱ㄴ적인 바람으로는 이 책 이후에 공부할 만한 중급, 고급 프로그래밍 교재도 많이 나와주었으면 한다. 책의 첫머리에 30일이면 이 책을 끝낼 수 있는 일정표가 있는데, 책 내요이 어렵지않아 누구나 쉽게 목표를 달성할 수 있을 것으로 생각한다.
# 얼마전 여동생이 파이썬을 공부한다고 모르는게 있으니 알려달라고 전화를 했었다. 어떤 강사가 강의를 하는데 기본적인 자료형이나 기초 문법에 대한 설명도 안하고 강의를 한 것이 문제였다. 나같은 프로그래머들이라면 아마도 이런 내용이겠거니~ 하고 따라갈 수 있지만 프로그램을 해 본적이 없는 초보라면 저게 뭐지?? 할 수밖에 없었던 것이다. 강의 대상이 초보자들을 상대로 한 것이었다는데... 강사가 수강자들의 수준을 고려하지 않고 대충 때우려고 생각했나보다. 덕분에 동생이나 동생같은 사람들은 분통을 터트렸지만 뭐 어쩌겠는가.
#
# 그래서 동생한테 도움이 될만한 책은 없는지 꼼꼼히 살펴보게 됐다. 어차피 나도 파이썬은 사용해본 적이 없기 때문에 내가 공부한다- 생각하고 찾아봤다. 오, 그런데 이 책이 참 마음에 들었다. 내가 딱~ 좋아하는 구성이다. 파이썬이 무엇인지에 대해서 먼저 설명부터 시작하는 부분이 제일 마음에 들었다.
#
# 파이썬의 특징, 활용, 한계를 가감없이 짧게 설명해 주고 있어서 파이썬을 매우려는 사람에게 정말 이 언어를 배워서 어떻게 어디까지 쓸 수 있을지 알 수 있도록 한다. 그리고 파이썬의 설치 및 실제 프로그래밍을 하기 위한 에디터의 소개를 시작으로 자료형에 대한 설명을 꼼꼼히 하고 그 다음에 차근차근 문법들을 알 수 있도록 했다. 마무리로 코딩면허시험 20제를 통해서 자신이 얼마나 파이썬 문법을 이해하고 있는지 확인할 수 있다.
#
# 파이썬의 설치 및 실행도 설명이 잘되어 있어서 금방 실행해 볼 수 있었다. 이제 이 책으로 그 불성실 강사 따위 잊어버리고 열심히 공부해보라고 동생에게 추천 줘야겠다. 쉽게 설치되고 쉽게 실행이 되는 것을 보니 나도 파이썬을 좀더 자세히 들여다보고 싶은 생각이 생겨서 앞으로 더 자세히 공부해봐야겠다. 처음 파이썬을 공부하시는 분들에게 추천하고 싶은 책이다.
#  <설명이 잘 되어 있어서 금방 테스트해 볼 수 있었다>
# <Do it! 점프투파이썬>이 4년만에 전면개정판이 나왔습니다. 오래전부터 파이썬 선배들이 권하는 단한권의 책 아닐까합니다. 물론 요즘 파이썬 책들이 무척많이 나왔습니다. 그래서 드문드문 새로운 책을 입문서로 권하기도 하지만 역시 <점프투파이썬>은 아직도 건재하고 앞으로도 한국에서 파이썬 입문서로써 빼기 힘든 책일겁니다. 기초부터 실전까지 자상하게 알려주는 베이직한 책이죠. 출판사인 이지스퍼블리싱에서 가장 많이 팔린책 아닐까하는 생각도 살짝드는 책입니다. 파이썬은 이제 이공대생뿐 아니라 경상대, 아니 일반 문과 대생까지도 익혀야할 컴퓨터 언어로 각광을 받고 있습니다. 언제부터인가 코딩능력에 대한 논의가 활발합니다. 어릴적에는 좀더 쉽게 알고리즘을 익히는 언어수단이 있지만 정말 프로그레밍을 해야할 시기에는 파이썬은 이젠 무조건 익혀야 하고, 구글 등 대부분 IT기업에 입사를 위해서는 필수로 익혀서 문제가지 풀어야 입사가 가능한 초보중에 초보 꼭 익숙해야 할 언어입니다. 파이썬 3.7까지 반영한 맞춤형 입문서가 맞는 듯합니다.
# <점프투파이썬>은 입문자가 접근할 수있게, 파이썬의 설치부터, 자료형처리법, 그리고 프로그램에서 항상 난관인 제어문도 충실히 다뤄줍니다. 사실 for, if, while 로 이루어지는 제어 조건문의 벽을 못넘으면 언어를 배우나 마나 하는 상황으로 치닫게 됩니다. 시간이 걸리더라도 for, if, while의 예는 좀더 다양한 내용을 인터넷 검색을 해서라도 익숙해 져야 앞으로 1년후에도 쓸모있는 프로그래머로 살수가 있을거겠죠.
# 2번짼 난관은 함수죠. def를 사용하여 사용자함수를 얼마나 잘 만드냐도 조건문만큼 중요합니다. 통계학을 공부하면 R이라는 언어를 배우게 됩니다. R이 일반 컴퓨터언어와 비슷해 보이지만 언어는 아니라고 하죠. 통계적 사용성에 좀더 촛점이 맞춰져서 그랫을겁니다. R도 함수기능이 당연히 있지만 파이썬 만큼 강력하지는 못할 겁니다. 다른 랭귀지에 비교해서도 좀더 쉽게 코딩이 가능하게 되어 있기 때문이겠죠.
# 파이썬으로 무엇하나는 처음 입문자들의 궁금증이죠. 더우기 파이썬이 처음인 인문대출신들은 더우기 감감하죠. 물론 딥러닝을 공부한다면 적혀 있는 코드를 따라쳐보다보면 실력이 늘게 되겠지만, 우선 기초적으로 적용하는 실전이 필요합니다. 그런 기회를 위해, 둘째 마당으로 파이썬 실력키우기로 6가지 예제를 다뤄줍니다. 그리고 정규표현식을 설명합니다. 고급주제죠. 복잡한 문자열처리하는데 매우 중요하다고 합니다. 저도 아직 익숙하지 못한 부분입니다만 ㅠㅠ 계속 반복해서 봐야 할 부분일겁니다.
# 끝에는 코딩먼허시험이라고 20제를 소개합니다. 자신의 파이썬 능력을 테스트할수있게 구성해두었습니다.
# 아참 책이 즐거워서 저자소개를 안했군요. 2001년 <점프투파이썬>2016년<Do it 점프투파이썬>을 펴낸 박응용으로 온라인책공유서비스를 하는 위키독스와코딩게시판 코딩도장 운영자이십니다. 세상의 속도를 따라잡고 싶으면 이 책을 봐야 할겁니다.
# 학교에서 코딩 교육을 정규과목으로 가르치기 시작하였습니다. 초등학교에서는 블록기반으로 코딩을 할 수 있는 엔트리와 같은 프로그램을 배우고 있습니다. 하지만, 엔트리와 같은 부류의 프로그램은 정식 텍스트 기반의 코딩을 이해하기 위한 초보 수준의 프로그램 입문용입니다. 정식으로 텍스트 기반의 코딩 공부를 시작할 때, 가장 많이 선택하는 것이 바로 파이썬이라고 합니다. 또한, 파이썬을 공부할 때 가장 많은 사람들이 사용했던 책이 바로 ‘Do it! 점프 투 파이썬’ 입니다. 이 책은 2016년 첫 출간 이후에 저자가 받은 피드백을 반영하여 초보자들이 더 잘 배울 수 있도록 전면 개정된 것입니다.
#   책에서는 총 7장의 내용을 기본 문법을 익히는 부분과 실력을 키우는 내용을 담은 두 부분으로 나뉘어 설명하고 있습니다. 책은 독학을 하는 초보자가 하루 1시간씩 공부하면 한 달 만에 모두 익힐 수 있는 구성이며, 학교에서 활용한다면 16주의 과정으로 할 수 있는 진도표도 각각 제공되어 있습니다. 가장 최신 버전의 프로그램을 기준으로 설치하는 과정부터 시작하며, 아주 간단한 사칙연산과 같은 기초 문법 설명을 통해 입력, 출력, 결과값, 변수 등이 무엇인지를 쉽게 설명하며 내용을 시작합니다. 또한, 프로그램 코딩에 도움이 되는 파이썬의 기본 IDLE 에디터는 물론이고 좀 더 많은 기능을 가지고 있는 유용한 에디터를 이용하는 방법도 알려주고 있습니다. 초보자들이 코딩 과정의 설명내용을 그대로 따라 할 수 있도록, 작성할 코드들은 순서대로 파란 배경과 함께 모두 실려 있습니다. 차분히 이 책과 함께 진도를 나간다면 어느덧 여러분도 프로그래머가 되어 있을 것입니다.
#   문법이 쉬워서 배우기 쉬운 프로그램이면서 오픈 소스로 무료로 사용할 수 있는 파이썬. 조금만 공부하여도 자료형, 함수, 클래스 만드는 법, 라이브러리 및 내장 함수 사용 방법을 금방 익힐 수 있기 때문에 처음 시작하는 사람도 바로 재미와 흥미를 느낄 수 있다고 생각됩니다. 또한, 이 책의 보너스로 네이버의 ‘Do it! 스터디룸’ 카페에서 운영하는 공부단에 지원하여 매일 공부한 내용을 스터디 노트에 작성하고 책을 완독하며 원하는 이지스퍼블리싱 책 1권을 선물로 둔다고 하니, 1석 2조의 혜택을 꼭 받으시기 바랍니다. ^^
# 파이썬 프로그래밍에 대해서는 예전부터 관심이 많았다. 얼마전 파이썬으로 데이터를 다루는 책을 보긴 했지만, 기본적인 것 부터 차근차근 다지는게 좋겠다는 생각이 들어 이 책으로 공부를 다시 시작했다. 이 책을 통해 다시금 느끼지만, 파이썬은 정말 흥미로운 언어이다. 기존의 다른 프로그래밍 언어들에 비해 상대적으로 짧은 문장으로 유사한 기능을 수행하게 할 수 있으며, 프로그래밍의 문법이 영어 문법과 유사하게 구성되어 다른 언어들에 비해 직관적인 이해가 가능하다.
#
# 이 책은 파이썬을 처음 시작하는 이들을 위해 만들어진 책답게 초보자의 눈높이에서 이해할 수 있는 용어들로 서술되어 있다. 고수들이 보면 굳이 이런것까지 설명해야 할까라고 느껴질만한 것도 친절히 설명되어 있는 것이 이 책의 특징인듯 하다. 1,2,3 장에서 파이썬의 개요와 기본적인 자료형, 제어문에 대해 설명하고 있는데, 거의 책의 반정도에 해당하는 분량을 할애하고 있다. 익숙해지게 되면 가장 쉬울수도 있는 부분이지만, 기초가 탄탄하지 않으면 높은 건물을 지을수 없듯이 가장 기본적인 부분을 꼼꼼히 이해할 수 있게 전달하고 있다. 덕분에 리스트와 튜플이라는 다른 언어에서 쉽게 볼 수 없는 자료형식에 대해서도 잘 이해할 수 있었다.
# 각 장의 말미에 제공되는 연습문제들도 훌륭한 실력향상 도구로 활용된다. 본문에서 따라하며 진행하던 예제들과 유사한 형태의 문제이긴 하나, 설명을 들으며 따라하는 것과 문제만을 보고 기억해서 코딩해 보는 것은 분명히 차이가 있었다.
#
# 파이썬을 처음 접하는 이들을 위한 책이기에 파이썬의 깊은 지식까지 바라는 이들에게는 부족한 도서로 보일 수도 있겠지만, 최근에 늘어난 코딩에는 관심에 응대하는 용도로는 훌륭한 교재가 될 수 있다. 책을 한 번 훑어보며 파이썬만의 개략적인 특징을 잘 이해할 수 있는 기회였으며, 다시 한번 정독하고 책의 말미에 제공되는 코딩면허시험까지 이수하고 난다면 초보 파이썬 프로그래머의 첫발을 잘 내딛을 수 있겠다는 생각이 든다. 책의 앞쪽엔 30일짜리와 16일짜리 두가지 공부용 커리큘럼이 제공된다. 본인의 기본 지식수준에 맞게 차분히 따라가다 보면 어느새 파이썬 프로그래머가 되어 있는 자신을 볼 수 있을 듯 하다.
# 서평을 시작하기전에 밝혀야 할 것이 두 가지가 있습니다. 이 평가는 이지스 퍼블리싱의 서평단에 발탁되어 책을 제공받고 작성하는 것이며, 저는 프로그래밍 입문을 파이썬으로 시작하는 것에 회의적인 입장입니다.
#
# 일단, 정말 프로그래밍을 처음 시작하는 사람들에게 추천을 해 줄 만큼 내용이 친절하게 적혀있지는 않습니다. 더욱이, 거의 파이썬 찬양에 가까운 파이썬 소개 문구는 매우 우려스럽습니다.
#
# 그렇기에, 이 책은 이미 프로그래밍에 대해서 알고 있는 사람이 파이썬을 처음 배울때 매우 적합한 책입니다. 각종 설명이 매우 간결하고, 코드 예시도 짧게 보여주기 때문입니다.
#
# 조금 더 직설적으로 말 하자면, 이 책은 프로그래밍 입문자가 보기에 친절한 책은 아닙니다. 입문자를 위해서라면 설명이 더 자세한 편이 좋을 것입니다. 더욱이 클래스 부분은 파이썬의 핵심이라고 한 것이 무색하게, 설명이 매우 짧게 되어 있으며, 일부 예시나 설명은 오히려 파이썬의 기능이나 프로그래밍의 개념을 오해할 수 있게 적어놓았습니다. 정규식의 언급은 불필요했다 생각됩니다.
#
# 결과적으로, 이미 다른 프로그래밍 언어에 익숙하신 분들은, 그런 설명들을 보며 회피할 건 회피하면서 프로그래밍을 할 수 있지만, 초보자는 그렇지 않기에, 이 책은 프로그래밍 경험이 있는 사람들에게 더 적합합니다.
# [이 서평은 이지스 퍼블리싱 서평단 이벤트에 당첨되어 제공받은 책을 읽고 작성하였습니다]
#
# 주로 파이썬 언어가 사용되는 AI 플랫폼의 개발총괄을 담당하고 있는 시니어 개발자입니다.
# 2010년대 들어 파이썬을 많이 활용하게 되었는데, 주변 주니어 개발자들이게 추천해줄만한 책을 찾다가
# 마침 이지스 퍼블리싱 서평단에 당첨되어 책을 받아 읽어보게 되었습니다.
# 꼼꼼하게 읽어보았는데, 확실히 파이썬으로 프로그래밍을 입문하는 사람들에게는
# 아주 쉽고 직관적으로 이해할 수 있게 잘 쓰인 책인 것 같습니다.
# 어떤 배경 지식이 있는 것으로 가정하고 쓰인 부분도 없었던 것 같고, 설명과 예제들이 친절하였습니다.
# 비전공자를 위한 프로그래밍 입문서로서 아주 훌륭한 책인 것 같습니다.
#
# 다만 이미 타 프로그래밍 언어에 익숙하거나,
# 프로그래밍을 처음 배우더라도 깊이 그리고 제대로 공부하고 싶은 사람들에게
# 추천하기에는 다소 망설여지는 것 같습니다.
# 예제들 중 일부가 아주 기초적인 글로벌 컨벤션을 준수하지 않았고,
# 엄밀하게 따지자면 틀린 설명이 종종 있었습니다.
# 파이써니스트로서는 조금 아쉬운 부분들이지만
# 이러한 부분들은 취미로 코딩을 하기에는 전혀 문제가 없기 때문에 큰 단점으로 꼽고 싶지는 않습니다.
# 그래도 만약 실제 파이썬 개발자가 되고 싶어하시는 분들
# 그리고 실제 상품화가 가능한 퀄리티의 코딩을 하고 싶으신 분들 중
# 이 책을 읽는 분들께는 반드시 공식 문서와 공신력있는 파이썬 커뮤니티를 통해
# 교차검증을 해보시길 적극 권장드립니다.
# [본 글은 이지스퍼블리싱에서 서평단으로 선정되어 책을 제공받았음을 알립니다]
#
#
# 코딩 10년차 코린이가 추천하는 최고의 입문책!
# Python 입문서로서 정말 흠 잡을 데 없는 책입니다.
#
# 책을 펼쳐보면 맨 처음 보이는 표지,
# '키보드만 잡으면 중학생도, 문과생도 쉽게 배운다'라고 적혀 있네요.
# 허위, 과장 광고는 아닌지 철저하게 '입문자'의 관점으로 책을 리뷰해보도록 하겠습니다 .^^
#
#
# 목차 뒤로 넘기면 이렇게 일정표가 있는데요,
# 정말 코딩을 아예 접해본적 없는 왕초보용 공부일정표와,
# 혹은 코딩 경험은 어느정도 있으나 파이썬이 처음인 분들을 위한 공부 일정표로 나뉘어져 있습니다.
# 개인적으로 일정표가 이렇게 짜여져서 나오는 책을 좋아합니다.
# 어느 정도 분량을 공부해야 지치지 않고 꾸준히 공부할 수 있는지 가이드라인을 주니까요,
# 특히 코딩을 아예 처음 접하는 분들에게 매우 좋을 것 같습니다.
#
#
#
# 그 다음 이렇게 실습 환경에 대해서 자세한 안내가 나와있는데요,
# 실습 환경같은 경우 대부분 프로그래밍 책에서는 생략하거나 간단하게 언급하는 경우가 많은데,
# 입문자 시절에는 가장 기본적인 환경 설정도 버거워하는 경우가 많죠.
# 그런 의미에서 입문자 여러분들을 위한 이런 세심한 배려도 돋보입니다 ^^
#
#
# 또한 본 책은 서로 지식을 공유할 수 있는 카페를 운영하고 있습니다.
# 코딩이라는게 혼자서 하다보면 반드시 막히는 부분이 생기기 마련인데,
# 이런 정보 공유의 장이 있다는 건 정말 좋네요.
#
#
#
# 첫 단원을 보면 아래와 같이 파이썬 설치부터 자세하게 나와있습니다.
#
#
# 설치 화면 하나하나 스크린샷을 떠서 어디를 선택하고, 안 해야 할지 자세히 알려주고 있네요.
# 입문자였을 때를 떠올려보면 코딩을 시작하기도 전에 환경 설정 및 인스톨에서 막혀서 답답해하곤 했는데, 이런 자세한 설명 정말 좋습니다.
#
#
# 들여쓰기를 단순히 Tab 키가 아닌 Spacebar 4칸으로 알려준 섬세함... 반했어요
# 입문자일 때 별 생각없이 Tab키를 많이 쓰곤 했는데요. 가끔 이게 문제가 될 때가 있죠 ㅠㅠ
# Tab = Sapcebar*4
# Tab 키가 문제가 되는 원인까진 입문자 수준에서 알아야 할 필요는 없으니 과감히 빼고,
# 대신 꼭 필요한 정보만 알려준 점도 정말 마음에 들었습니다.
#
#
#
# 여러 줄 주석은 코딩할 때 꼭 필요하죠.
# 이런 꿀팁 및 꼭 필요한 정보들을 박스로 따로 표시해두었습니다.
#
#
# 그리고 큰 내용이 하나 끝날 때마다 아래와 같은 미니문제들이 나오는데요.
# 정답이 바로 나와있어서 굳이 뒷장으로 답을 찾아갈 필요는 없다는 장점이 있지만,
# 정답을 의도치 않게 미리 봐버릴 수도 있다는 단점이 있네요 ㅠ
# 그리고 이런 미니 문제가 많으면 코딩에 숙련되는데에 도움이 될 거 같은데,
# 문제 수가 그닥 많지 않다는 점은 제가 생각하는 이 책의 유일한 단점입니다.
#
#
# 모든 단원을 공부하고 나면 아래와 같은 코딩 면허 시험을 치를 수 있어요.
# 미니문제보단 조금 더 난이도가 있고, 제가 어떤 파트에서 어떤 지식이 부족한지 알 수 있게 해주네요.
#
#
#
# 면허 시험 문제를 약간 맛보자면 아래와 같습니다.
#
#
# 해설은 아래와 같이 코드와 그 코드에 대한 해설이 함께 붙어있는 형식입니다.
# 코드만 딸랑 있는게 아니라 코드에 해설이 함께 붙었다는 점이 마음에 드네요.
# 다만, 코딩에는 정도가 있는게 아니라 같은 솔루션을 내더라도 다양한 방법으로 코딩해 볼 수 있는데,
# 문제당 한가지씩의 솔루션만을 제시한 것은 약간의 아쉬움으로 남습니다.
#
#
#
# 지금까지 올해 6월에 전면 개정된 'Do it! 점프 투 파이썬'을 리뷰해보았습니다.
# 저는 개정 전 책은 가지고 있지 않았고 jump to python wikidocs만을 참고해서 공부했었는데요.
# 책은 단순히 wiki 내용을 그대로 출력하기만 한 줄 알았는데, 그게 아니라 훨씬 풍부한 내용과 해설을 담고 있더라고요.
# 무엇보다 입문자의 관점에서 정말 친절하고 자세하게 쓰여진 책이니, 파이썬 입문자라면 고민없이 이 책을 선택하시면 될 것 같습니다 . ^^
#
# 제가 코딩에 입문할 당시만 해도 이런 자세한 입문서는 꿈도 꾸지 못했습니다.
# 당연하다는 듯한 흑백 인쇄에, 설치 정도는 알아서 할 수 있지? 라는 뉘앙스의 intro, 그리고 입문자로서는 생소하기만 한 개발 용어들의 난무로 코딩 입문이 되게 버겁게 느껴졌었죠.
#
# 요즘 코딩 열풍이 과하게(?) 불면서 코딩 입문자 분들이 갑자기 늘어난 것으로 아는데,
# 덕분에 이런 친절한 입문서들이 등장을 하게 되어서 기쁘네요.
#
# 프로그래밍을 가르치면서 가끔은 입문자의 마음을 잊고 (개구리 올챙이 적 생각 못하고 ^^;)
# 이건 당연히 알겠지? 라는 마음가짐으로 휙휙 넘어갈 때가 있는데,,
# 그런 저의 모습을 반성하게 하는 책이었습니다.
#
# 입문자 여러분, 코딩은 그렇게 어렵지 않습니다.
# 이 책의 말대로 누구나 쉽게 배울 수 있으니, 자신감을 갖고 도전해 보시길 바랍니다.
#
# 좋은 책을 서평할 기회를 주신 이지스퍼블리싱에 감사드리며, 이 리뷰를 마칩니다. ^^
# 이지스 퍼블리싱의 서평단 이벤트에 당첨되어 읽어 봤습니다.
# 요새 핫한 언어인 파이썬에 관심이 있어 초심자의 마음으로 책을 읽어봤는데요.
# 기존에 프로그래머가 아니더라도 책의 내용을 이해하는데 어려움이 없을 정도로
# 설명이 쉬우면서도 체계적이고, 예제가 많아 적용해 볼 기회도 많았습니다.
# 프로그래밍 기초 지식을 모두 알 수 있도록 커리큘럼이 짜여져 있는 책이기 때문에
# 프로그래밍을 처음 시작하는 사람들이 필독했으면 하는 책입니다.
# 책의 마지막엔 코딩 면허 시험이라고 하여 배운 내용을 모두 체크해 볼 수 있는데,
# 이로 인해 자신의 부족한 부분을 알 수 있어 좋았습니다.
# 프로그래머 입문자 혹은 파이썬을 처음 시작하는 분들께 자신있게 추천 할 수 있는 책입니다.
#  요즘 가장 인기있는 프로그래밍 언어 중 하나가 파이썬이다.
# 4차 산업혁명의 핵심 기술인 빅데이터와 인공지능 등의 인기는 이를 보다 쉽고 정확하게 표현하고 구현할 수 있는 언어에도 영향을 끼쳤다.
# 게다가 중등 교육과정의 창의력 증진을 위해 파이썬이 권장되고 있다.
# 예전에는 학술 연구용으로 많이 쓰이던 파이썬이 점점 대중화되고 있는 것 같다.
#
# 파이썬은 오픈소스로 누구나 사용할 수 있고, 다른 언어에 비해 비교적 쉽게(?) 공부할 수 있다는 장점이 있다.
# 이 파이썬을 공부하는 사람 중 대다수가 처음으로 보는 가이드가 바로 이 책 'Do it! 점프 투 파이썬'이다.
# 온라인으로도 제공되고 있는 'Do it! 점프 투 파이썬' 개정판이 책으로 출간됐다.
#
#
# 개인적인 취향이겠지만 온라인에서 보는 문서보다는 한장한장 넘겨가면서 볼 수 있는 책이 아직은 편하고 좋다.
#
# 이 책은 개정판답게 최신의 파이썬 버전의 소스를 제공하고 있다.
# 파이썬에 대한 간략한 설명과 설치로 시작한다.
# 그리고 기초적인 내용과 구조에 대해서도 쉽게 설명하고 있다.
# 책의 마지막에 있는 '코딩 면허 시험'은 앞부분에서 배운 내용들을 얼마나 제대로 숙지하고 응용할 수 있는지 스스로 확인할 수 있도록 되어 있다.
# 별표로 난이도가 표시되어 있어 정말 시험을 준비하는 듯한 기분이 든다. ㅎㅎㅎ
#
# 책을 한장한장 넘기다 보니 왜 이 책이 최고의 파이썬 입문서인자를 알게 되었다.
# 표지에 있는 글처럼 전공자가 아니더라도 이 책의 내용을 이해하는데 어려움이 없다.
# 그냥 한줄한줄 따라가면 된다.
#
# "Life is too short, You need Python!"
# 짧은 인생에 왜 파이썬이 필요한지 직접 느껴보시길~
# 점프 투 파이썬 표지 <출처 : 이지스 퍼블리싱 홈페이지>
# <이 서평은 페이스북 그룹인 Python Korea에서 진행된 서평단 이벤트로
# 이지스 퍼블리싱에서 제공된 책으로 작성한 글입니다.>
#
# 안녕하세요. 오랜만에 서평을 적게 된 김성민입니다.
# 최근 머신러닝 공부를 하기 위해 파이썬 문법을 공부하면서 Facebook그룹인 Python Korea 커뮤니티에서 파이썬 책중 가장 유명한
# 점프 투 파이썬 책 서평단을 모집하는 글을 보고 신청하여 서평단으로 선정이 되어 글을 적게 되었습니다.
# 커뮤니티에 올라온 서평단 모집 게시물
# 저는 기존 개정판 전 책을 구매하여 공부하고 있었기 때문에 기존 책과 차이점을 중심으로 글을 작성하려고 합니다.
#
# 점프 투 파이썬 책은 파이썬을 공부하는 사람이라면 누구나 한 번쯤은 들었봤을만한 유명한 책이고 위키 독스를 통해 누구나 책과 동일한 내용으로 공부할 수 있도록 제공해주기 때문에 많은 사람들이 이 책을 보고 공부했을 겁니다.
# 우선 기존 책과 가장 큰 차이점을 보기 위해 책 디자인을 시작으로  살펴보도록 하겠습니다.
# 1. 책 디자인
# 책 표지의 경우 위 사진과 같으며 바뀐 점은 매번 출시될 때 업데이트되는 글씨 내용을 제외하곤 동일합니다.
# 전체적인 책 디자인 및 내용은 똑같습니다. 다른 점이 있다면 제가 기존에 소지한 책의 경우 전체적인 글과 그림들이 갈색으로 구성되어 있었다면 개정판의 경우 파란색으로 구성되어 있습니다.
# 개정판이 파란색으로 구성되어 있는 탓인지 글을 읽을 때 다소 편한 감이 있었습니다.
# 2. 목차
# 기존 책과 달라진 점은 7-4장인 파이썬으로 XML 처리하기 부분이 제거되었습니다.
# 기본적인 목차는 기존 책과 동일하고 내용 또한 같습니다.
# 기존 소지한 책의 목차
# 개정판 목차
# 3. 실습 문제
# 기존 책에도 보면 각 파트별 1-2문제 정도 연습 문제가 존재하였습니다.
# 하지만 개정판의 경우 각 장별 20문제 정도 연습 문제가 존재하여 공부를 하면서 문법을 익히기 위해 인터넷에서 문제를 검색하여
# 공부를 하는 것이 아닌 책에 있는 문제를 통해서도 문법을 사용하여 간단한 알고리즘 문제를 해결할 수 있게 되었습니다.
# 저는 이부분이 가장 마음에 들었습니다.
# 이 책의 경우 꾸준히 사랑받고 있는 책이며 파이썬 문법을 공부한다고 하면 누구나 한번쯤은 보고 공부한 책인 만큼 유명한 책입니다.
# 또한 최근 인공지능 과 백엔드 관련 공부를 하는 학생들이 많아지고 있고 프로그래밍 입문자가 배우기 쉬운 언어로 파이썬을 많이 추천 하는 시대인 만큼 많은 사람들이 이 책을 보고 파이썬을 공부하였으면 좋겠습니다.
# 또한 위키독스를 통해 책의 내용을 공부도 할 수 있지만 인터넷이 아닌 책으로 직접 공부하는 방법도 좋은 방법 인거 같습니다.
# 이지스 퍼블리싱의 서평단이벤트에 당첨되어 파이썬을 다시한번 공부한 독자입니다!
#
# 점프 투 파이썬은 파이썬을 공부하기에 가장 좋은 책 중 하나라고 생각합니다.
#
# 파이썬 순수 언어 관련 책만 3~4권정도 읽은거같은데, 점프 투 파이썬처럼 얇고 꼭 필요한 내용만 들어가 있는 책은 본 적이 별로 없습니다.
#
# 기본문법과 자료구조는 1주일이면 공부할 수 있고, 그 뒤는 실전으로 이루어져있죠.
#
# 한달도 필요없고, 2주 조금 넘는 기간이면 파이썬을 끝낼 수 있는 책입니다.
#
# 챕터를 끝낼 때마다 기본적인 예제를 직접 풀어볼 수 있으며, Do it 시리즈 카페도 있어서 혼자 공부하는 것이 아닌 다른 스터디원들과 함께하는 공부를 진행할 수 있어서 좋아요.
#
# 파이썬은 간결한 문법과 인터프리터 기반의 언어라서 머신러닝과 데이터 사이언스 분야에서 가장 각광받고 있는 언어이니 꼭 공부해볼 필요가 있습니다.
# 자세한 설명과 보기 좋게 잘 정리되어 좋았습니다.
#
# 기초적인 부분부터 약간의 프로그램 응용이 필요한 부분도 보완되어 있는것 같습니다.
#
# 챕터를 마칠 때 마다 간단한 기출문제로 공부한 지식을 다시 한번 점검 할 수 있는 좋은 구성과 주요한 내용은 한 번 더 반복해서 알려주는 책으로써 누구나 쉽게 접하고 이해할 수 있었습니다.
#
# 저와 같이 처음으로 파이썬을 접하거나, 프로그래밍에 입문하시는 분들에게 꼭 추천해드립니다.
# 나도 코딩이나 배워볼까?
#  사람들의 일상적이 대화속에서 흔히 들을수있는 말이다.
# 독학으로 코딩을 부담없이 즐기며 배우고 싶은 분들에게 이 책을 추천한다.
#  "점프 투 파이썬"은 최근 개정되었다.
# 개정되기 이전 책과 개정판을 비교해보았는데, 많은 부분이 변하였다.
# 최근 업데이트된 파이썬 3.7버전 기분으로 작성된것은 기본이고, "나혼자 코딩" 부분과 "코딩 면허 시험 20제"까지 더해서 연습문제를 풀기 전에 먼저 내용을 익혀두고 더 많은 문제를 풀어볼수 있었다.
# 또한, 색 하나하나까지 세세하게 바꿔서 어떠한 부분에서 쉘과 에디터를 써야하는지, cmd창을 키는지 쉽게 구분할수있도록 바꾼 부분이 저자가 정말 열심히 독자들과 소통하며 노력한다는 점을 느낄수 있었다.
#  "점프 투 파이썬"은 초보자들을 위해 30일 계획표, 공부단 등을 제공하고 있어 초보자가 하나하나 꾸준히 노력하여 코딩에 세계에 빠져들수 있도록 도움을 주고있다.
# (더군다나 파이썬 자체의 장점이 매우 쉽고 간결하기 때문에 효과는 더욱 증가하였다)
#  이 글을 읽는 분들도 점프 투 파이썬과 함꼐 코딩의 세계에 빠져들기 바란다.
#
# Life is too short, you need python!
#
#   1학년때 교수님께서 말씀하시길 "방학때 놀지 말고 한 달만 투자하면 너희 모두 python 마스터다!"라고 하셨습니다.
# 그 이야기를 듣고 'C나 공부하지 왜 python함?' 이라고 생각했지만 주변 사람들은 점점 python을 사용해가고 있고 결국 제게도 python이 필요하게 되었습니다.
#
#   python 공부를 위해서 구글링 하다가 결국 2가지 책을 고르게 되었는데 하나는 두껍고 양많은 책이었고 다른 하나는 점프 투 파이썬 이었습니다. 코드는 책보고 하는거 아니라고 이야기하는 사람들이 있었지만 1학년 때 공부한 C 언어 말고는 경험이 없어서 책을 보는게 나을거라고 생각했습니다.
#
#   점프 투 파이썬은 p265를 기준으로 앞은 기본 문법, 뒤는 응용 + 정규표현식으로 볼 수 있는데 265페이지라는 얇은 책에 필요한 기본 틀과 예제, 연습문제가 모두 들어있습니다. 저는 코드를 공부하는데 필요한 것은 기본에 충실한 책과 구글링 그리고 지속적인 관심이라고 생각합니다.
#
#   기본에 충실한 책과 구글링은 이미 여기에 준비되어있습니다!
# https://cafe.naver.com/doitstudyroom
# 위 링크는 Do it! 책을 공부하는 여러 사람들과 소통할 수 있는 스터디 카페입니다. 공부단이라는 프로그램도 진행하니 공부하시면서 스터디 노트도 작성해보시고 여러 사람들과 의견을 나누면서 지속적으로 프로그래밍 언어에 관심을 갖을 수 있습니다. 저도 공부단 하면서 얻는게 많아서 이렇게 추천드립니다!
#
# 읽어주셔서 감사합니다 :) 즐거운 코딩하세요!
#  바야흐로 코딩 전성시대입니다. 4차 산업혁명이 화두로 떠오르면서 그야말로 광풍이라는 단어가 과장이 아닐만큼 코딩에 대한 관심이 그 어느 때보다 뜨거운 요즘입니다. 코딩이 교육과정에서 필수가 되고, 유치원생을 대상으로한 코딩 프로그램이 낯설지 않을 지경입니다. 이과 전공자뿐만 아니라 이제는 문과생도 코딩이 필수인 시대입니다.
#
#  저 또한 새해 목표를 몇 년째 제자리걸음인 영어완전정복에서 코딩 마스터로 올해부터는 슬그머니 바꾸었습니다. 하지만 외국어인 영어만큼이나 프로그래밍 언어인 코딩을 익히기는 쉽지 않았습니다. 그러다보니 영어학습에서 뿌리치지 못한 못된 습관이 코딩 배우기에도 나타났습니다. 꾸준하고 열정적인 학습보다는 부화뇌동하며 남들이 좋다는 책이나 강의를 따라하며 수박 겉핥기를 반복하고 있었습니다.
#  그러다가 이번 리뷰 이벤트를 통해 Do it! 점프 투 파이썬[개정판]을 만나게 되었습니다. 파이썬 4년 연속 베스트셀러 1위! 라는 자극적인 문구가 이 책의 첫인상이었습니다. 그 다음으로는 전면개정판이라는 문구가 뒤를 따랐습니다. 마지막으로 '키보드만 잡으면 중학생도, 문과생도 쉽게 배운다!' 문장에서 새로운 희망과 용기를 얻을 수 있었습니다. 첫인상이 주는 편안함을 바탕으로 이번에는 틀림없이 파이썬과 친해지리라는 굳은 다짐과 함께 책을 차근차근 읽어보았습니다.
#
#  이 책이 가지는 가장 큰 장점은 바로 분량입니다. 360 페이지라는 프로그래밍 서적으로는 상당히 적은(?)  페이지수를 자랑합니다. 두꺼운 사전을 방불케하는 책을 많이 바온 저로서는 이렇게 슬림한 책을 만나니 그저 반갑기만 합니다. 적절한 분량을 짧은 시간 안에 쳬계적으로 학습할 수 있는 계획표를 제공하기에 독학용으로도 교재용으로도 손색이 없습니다.
#
#  분량이 적으면 당연히 내용의 부실함을 걱정하지 않을 수 없습니다. 하지만 이 책은 2008년부터 위키독스라는 온라인 사이트를 통해 독자들과 소통해 왔습니다. “사실 이 책의 저자는 필자 한 사람이 아니다. 위키독스에 달린 무수한 댓글을 보면 알 수 있다.”라는 저자의 말처럼 이 책은 독자와의 소통을 통해 무수한 업데이트를 반영한 그야말로 전면 개정판입니다. 특히 복장한 내용을 명쾌한 설명으로 그치지 않고 풍부한 예제를 통해서 독자가 직접 실행해 볼 수 있다는 점에서 높은 점수를 주지 않을 수 없습니다.
#
#  특히 개인적으로 맘에 들었던 부분은 07장 정규 표현식입니다. 정규 표현식은 다른 두꺼운 기본서들도 아예 빠뜨리거나 부실하게 넣어놓기 쉬운 부분입니다. 아예 책 한 권을 따로 낼만큼 복잡한 내용이기도 합니다. 이런 부분을 놓치지 않고 명쾌하게 설명한 저자의 혜안에 감탄하지 않을 수 없습니다. 물론 이 책 한 권으로 파이썬을 정복한다는 것은 쉽지 않은 일입니다. 하지만 적절한 분량과 체계적인 계획 아래 꾸준하게 연마해 나간다면 중학생도 문과생도 머지않아 파이썬을 사랑하고 활용하는 날이 오리라 확신하며 일독을 권합니다.
#
# <이 글은 해당 출판사에서 제공받은 책을 읽고 쓴 리뷰입니다. >
# 10년전 20년 전만 해도 처음 프로그래밍을 시작하는 언어로는 C 혹은 JAVA로 많이 추천을 했다. 최근 2-3년 전부터는 프로그래밍을 처음 시작하는 입문자들에게 망설임 없이 말한다. 파이썬으로 시작하는게 좋다. 그 이유는 쉽고 재밌다.
#
# 요즘은 빅데이터 관련 분야에는 어김없이 파이썬 라이브러리를 사용한다. 파이썬을 모르면 빅데이터 딥러닝을 모른다고 해도 과언이 아니다. 그래서 파이썬은 이제 선택이 아니라 필수 언어로 각인되고 있다.
#
# 시중에는 엄청나게 많은 파이썬 책들이 쏟아져 나온다. 그 중에서도 가장 눈이 띄는것이 Do it! 점프 투 파이썬 개정판이였다. 국내 최초 2001년 점프 투 파이썬 책을 집필한 저자이고 13년 동안 독자의 질문에 잘 피드백을 반영하여 초보자가 더 빠르게 입문하고 더 깊이 있게 공부 할 수 있도록 구성되어 있다.
#
# Do it! 점프 투 파이썬으로 이미 수많은 독자가 프로그래밍에 입문한 교재로 믿고 공부 할수 있다. 특히 독학용 학습 계획표와 교재용 계획표를 따로 제공 하고 있어 학교 교재든 독학용으로도 손색이 없다. 혼자 공부 한다면 독학용 30일 코스로 하루 한시간 한달이면 누구나 파이썬 프로그래밍을 익숙하게 할수 있을것이다.
#
# Do it! 점프 투 파이썬은 철저하게 눈높이를 입문자에서 맞쳐져 있다. 처음 배우는 사람에게 맞게 쉽고 간결하게 잘 설명 하고 있다. 프로그램을 잘모르는 사람도 소설책 읽듯이 술술 읽을 수있게 되어있다. 처음 부터 끝까지 한땀 한땀 실습 하다보면 어느덧 파이썬 문법이 머리 보다 손이 먼저 기억하게 되는 기적을 맛보게 될것이다.
#
# 그리고 기존의 Do it! 점프투 파이썬책을 가지고 있는 사람에게는 개정판에 새로 추가된 ‘코딩 면서 시험20제’는 무료로 제공하고 있다. 이지스퍼블리싱 홈페이지에서 무료 PDF파일을 받을수 있다.
#
# 마지막으로 Do it! 점프 투 파이썬은 프로그래밍이 어렵다고 생각하는 사람 기존에 다른 언어를 공부를 했는데 어려워서 포기한 사람 처음 프로그래밍 시작하는 사람들에게 추천 합니다.
# 개인적으로 파이선 코드가 보기 좋게 잘 정리되어 좋았습니다. 기초적 인부분부터 약간의 응용이 필요한 부분까지.
#
# 중간중간에 어우러져 있는 간단한 기출문제로 각 챕터에서 공부한 지식을 점검할 수 있는 좋은 구성으로 되어있습니다. 주요한 내용은 한 번 더 반복해서 알려주는 책으로써 누구나 쉽게 이해할 수 있도록 쓰여 있습니다.
#
# 처음으로 파이선을 하거나, 프로그래밍에 입문하시는 분들에게 꼭 추천해드리고 싶은 책입니다.
# Do it! 점프 투 파이썬 [ 개정판 ]
#
#
# 저도 직장을 다니고 있지만 이번에 이책을   읽어보면서 대단히  점프 투 파이썬
#
#
# 대학졸업후에  관련 컴퓨터 학과출신이지만  30대초반 직장인입니다. 프로그램 프로그래밍에 대하여 다시한번 배워보려고 하니까
# 어렵고  내용마저도 쉽게 접근이 어려워서   조금더 쉽게  접근을 하면서  기본적인 내용을  배워보고 싶은데 이번에 새롭게
#
# 개정판 출시로 통하여
#
#  파이썬 프로그래밍의 기초  자료  제어   그리고 입력과 출력   처음 시작하는 사람과  기존에   관련 내용을 배우고자 하는
#
# 사람도 그만큼 관심을 가지고 접근을 하면 좋습니다.
# 퇴근후에 책을 보면서 10~20분정도 해보니까  나름 실력도 늘어나고  파이썬처음에는   어려울것 같은데 이제는  아내랑 같이  배워보고 있어요
#
# 남녀노소  시간이 나면서  취미삼아서  기초를 떠나서  전문가의 관점에서  실력을 늘릴수가 있어서 좋습니다.
# 4차 산업혁명시대를 제대로 준비하기 위해 인공지능 머신러닝에 주로 사용되는 파이썬은 이제 선택이 아니라 필수라 할 수 있겠다. 머신러닝을 배우면서 처음으로 파이썬을 접했는데 기본적인 문법도 모른채 프로그래머의 감각으로 짐작하며 공부를 진행했었다. 기본적인 머신러닝 공부를 마치고 파이썬에 대한 체계적 배움에 대한 갈망이 있었는데 그때 'Do it! 점프 투 파이썬' 책을 만났다.
# 파이썬을 처음 배우고자 하는 분들에게 가장 정합한 책이라 생각된다. 기초부터 차근차근 많은 예제와 체계적 설명이 군더덕이 없어 더욱 좋은 도서인 것 같다.
# 파이썬을 배우고 싶은 분들에게 주저없이 권하고 싶은 도서다.
# 파이썬을 처음 공부하는 입장으로써 입문서로 딱인 책입니다.
#
#
# 다만 기본서 위주라서 더깊은 내용을 공부하고 싶은사람들은 다른책을 겸비해서 사는것을 추천드립니다.
#
#
# 프로그램 코딩에 대해 처음배우시는 분들도 거리낌없이 쉽게 다가갈수 있도록 안내하는게 마음에듭니다.
#
#
# 역시 전체 프로그래밍 분야 4년 연속 베스트셀러 1위라는 결과에 맞는 좋은 책인거같습니다.
#
#
# 결론은 내용면에선 기초는 좋지만 심화과정은 없는 부분에서 좀아쉬었지만 초보자 입장에서 쉽게 배울수있단는 점이좋았고 편집과 구성부분은 5점입니다.
